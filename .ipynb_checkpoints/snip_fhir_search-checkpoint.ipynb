# %% [markdown]
# **Author: Alexander Kollmann, 09/2022**
#
# ---
#
# **Funktion**
#
# FHIR - Abfragen und Suchen (nativ und mittels fhirclient)
#
# *   einfache Suche über im Standard definierte Such-Parameter (? bzw. &)
# *   Verkettete Suche über Referenzen
# *   Inkludieren von Referenzierten Ressourcen in das Ergebnis
# *   AddOn (z.B. Konvertierung des Suchergebnisses (JSON Bundle) in ein Pandas Dataframe)
#
#
#
#
# ---
#
#
#
# **Referenzen**
#
# https://learn.microsoft.com/en-us/azure/healthcare-apis/fhir/search-samples
#
# https://cloud.google.com/healthcare-api/docs/how-tos/fhir-advanced-search
#
# https://developer.commure.com/docs/apis/fhir/search-parameters/
#
# https://colab.research.google.com/drive/1OSuqqACnCqw8h67E7DKDMyIGO1C2qbEq?usp=sharing
#
# https://developer.commure.com/docs/apis/fhir/search-parameters/
#
#
# ---

# %%
import json
import requests
from collections import OrderedDict
from io import StringIO
from IPython.display import IFrame

# %%
# Define Base URL
url = "http://hapi.fhir.org/baseR4/" # Open HAPI FHIR Server
#url = "https://server.fire.ly/R4/" # Open Firely Server
headers = {"Content-Type": "application/fhir+json;charset=utf-8"}

# %%
# now add some search parameters

# each FHIR resource type has its own set of parameters; find them toward the bottom of the page for that resource type in the specification
# for example, for the Patient resource type, see https://www.hl7.org/fhir/patient.html#search
IFrame('https://www.hl7.org/fhir/patient.html#search', width=1200, height=500)
# Out:
#         <iframe
#             width="1200"
#             height="500"
#             src="https://www.hl7.org/fhir/patient.html#search"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Einfache Suche

# %%
# Abfrage nach Name UND Geburtsdatum
# Erwartetes Ergebnis: 1 Treffer

req = url + "Patient?" + "birthdate" + "=" + "2022-12-05" + "&" + "name" + "=" + "WienerNeustadtNJrLm"
#req = url + "Patient?" + "birthdate" + "=" + "2022-12-05"
print(req)
response = requests.request("GET", req, headers=headers)
result = response.json()
patient_id = result['entry'][0]['resource']['id']
print(response.text)
# Out:
# http://hapi.fhir.org/baseR4/Patient?birthdate=2022-12-05&name=WienerNeustadtNJrLm
# {
#   "resourceType": "Bundle",
#   "id": "9bdf1512-3fda-4bbc-bfda-c674d6a65fbe",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:35:32.601+00:00"
#   },
#   "type": "searchset",
#   "total": 1,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?birthdate=2022-12-05&name=WienerNeustadtNJrLm"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185197",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185197",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:33:01.605+00:00",
#         "source": "#2eopjhS2NavITyoA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNJRLM </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNJrLm",
#         "family": "WienerNeustadtNJrLm",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
#print(response.text)
patient_id
# Out:
# '7185197'

# %%
# Abfrage der Condition zu einem Patienten

# Teatpatient: MrXXX
#patient_id = str(7168516)
# Get Condition of this patient
req = url + "Condition?" + "patient=" + patient_id
response = requests.request("GET", req, headers=headers)
print("Anzahl: " + str(json.loads(response.text)['total']))
print(response.text)
# Out:
# Anzahl: 2
# {
#   "resourceType": "Bundle",
#   "id": "e2832df1-600d-49c5-8498-8d291f1d8ec8",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:12.005+00:00"
#   },
#   "type": "searchset",
#   "total": 2,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Condition?patient=7185197"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185205",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185205",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:36:47.234+00:00",
#         "source": "#fkx8L0bIRfV87Kw3"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185197"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185206",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185206",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:39:04.904+00:00",
#         "source": "#1HGvYIjOmEpnmBfq"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185197"
#       },
#       "encounter": {
#         "reference": "Encounter/7185198"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Search Observations with the term ‘Cholesterol’’ in text description.

req = url + "Observation?_text=Cholesterol"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "4219227d-69ed-41e5-aa14-1223fe3a651d",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:13.765+00:00"
#   },
#   "type": "searchset",
#   "total": 8,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Observation?_text=Cholesterol"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/10766535",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "10766535",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-06-22T17:16:01.534+00:00",
#         "source": "#VuSVL37MTcEJHVZG",
#         "profile": [ "https://nrces.in/ndhm/fhir/r4/StructureDefinition/Observation" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Narrative with Details</b></p><p><b>id</b>: lab-example-01</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol <span>(Details : LOINC code '35200-5' = 'Cholesterol [Mass or Moles/volume] in Serum or Plasma', given as 'Cholesterol [Moles/​volume] in Serum or Plasma')</span></p><p><b>subject</b>: ABC</p><p><b>performer</b>: XYZ Lab Pvt.Ltd.</p><p><b>value</b>: 6.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>4.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "35200-5",
#           "display": "Cholesterol [Mass or Moles/volume] in Serum or Plasma"
#         } ],
#         "text": "Cholesterol [Mass or moles/Vol]"
#       },
#       "subject": {
#         "reference": "Patient/10766189"
#       },
#       "performer": [ {
#         "reference": "Organization/10766297"
#       } ],
#       "valueQuantity": {
#         "value": 6.3,
#         "unit": "mmol/l",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "high": {
#           "value": 4.5,
#           "unit": "mmol/l",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/10767143",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "10767143",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-06-22T18:02:44.301+00:00",
#         "source": "#h6qyiwUIgwIQD9xc",
#         "profile": [ "https://nrces.in/ndhm/fhir/r4/StructureDefinition/Observation" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Narrative with Details</b></p><p><b>id</b>: lab-example-01</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol <span>(Details : LOINC code '35200-5' = 'Cholesterol [Mass or Moles/volume] in Serum or Plasma', given as 'Cholesterol [Moles/​volume] in Serum or Plasma')</span></p><p><b>subject</b>: ABC</p><p><b>performer</b>: XYZ Lab Pvt.Ltd.</p><p><b>value</b>: 6.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>4.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "35200-5",
#           "display": "Cholesterol [Mass or Moles/volume] in Serum or Plasma"
#         } ],
#         "text": "Cholesterol [Mass or moles/Vol]"
#       },
#       "subject": {
#         "reference": "Patient/10766189"
#       },
#       "performer": [ {
#         "reference": "Organization/10766297"
#       } ],
#       "valueQuantity": {
#         "value": 6.3,
#         "unit": "mmol/l",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "high": {
#           "value": 4.5,
#           "unit": "mmol/l",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/10767171",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "10767171",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-06-22T18:06:56.255+00:00",
#         "source": "#1V6ENRoJjjO8BIqh"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Narrative with Details</b></p><p><b>id</b>: lab-example-01</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol <span>(Details : LOINC code '35200-5' = 'Cholesterol [Mass or Moles/volume] in Serum or Plasma', given as 'Cholesterol [Moles/​volume] in Serum or Plasma')</span></p><p><b>subject</b>: ABC</p><p><b>performer</b>: XYZ Lab Pvt.Ltd.</p><p><b>value</b>: 6.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>4.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "35200-5",
#           "display": "Cholesterol [Mass or Moles/volume] in Serum or Plasma"
#         } ],
#         "text": "Cholesterol [Mass or moles/Vol]"
#       },
#       "subject": {
#         "reference": "Patient/10766189"
#       },
#       "performer": [ {
#         "reference": "Organization/10766297"
#       } ],
#       "valueQuantity": {
#         "value": 6.3,
#         "unit": "mmol/l",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "high": {
#           "value": 4.5,
#           "unit": "mmol/l",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/39402",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "39402",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-01T18:39:29.193+00:00",
#         "source": "#9e8319c22dbc9c4d"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: ldlcholesterol</p><p><b>status</b>: final</p><p><b>code</b>: LDL Chol. (Calc) <span>(Details : {LOINC code '13457-7' = 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation', given as 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation'})</span></p><p><b>subject</b>: <a>Patient/1200</a></p><p><b>performer</b>: <a>Acme Laboratory, Inc</a></p><p><b>value</b>: 4.6 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>3.0 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "13457-7",
#           "display": "Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation"
#         } ],
#         "text": "LDL Chol. (Calc)"
#       },
#       "subject": {
#         "reference": "Patient/1200"
#       },
#       "performer": [ {
#         "reference": "Organization/1621",
#         "display": "Acme Laboratory, Inc"
#       } ],
#       "valueQuantity": {
#         "value": 4.6,
#         "unit": "mmol/L",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "high": {
#           "value": 3.0,
#           "unit": "mmol/L",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/hdlcholesterol1",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "hdlcholesterol1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-09-09T20:50:08.077+00:00",
#         "source": "#N4tTkWSdxX9GXtmn"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: hdlcholesterol</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol in HDL <span>(Details : {LOINC code '2085-9' = 'Cholesterol in HDL [Mass/volume] in Serum or Plasma', given as 'HDL Cholesterol'})</span></p><p><b>subject</b>: <a>Patient/Patient1</a></p><p><b>performer</b>: <a>Acme Laboratory, Inc</a></p><p><b>value</b>: 1.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>Low</b></td></tr><tr><td>*</td><td>1.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "2085-9",
#           "display": "HDL Cholesterol"
#         } ],
#         "text": "Cholesterol in HDL"
#       },
#       "subject": {
#         "reference": "Patient/Patient1"
#       },
#       "performer": [ {
#         "reference": "Organization/Org1",
#         "display": "Acme Laboratory, Inc"
#       } ],
#       "valueQuantity": {
#         "value": 1.3,
#         "unit": "mmol/L",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "low": {
#           "value": 1.5,
#           "unit": "mmol/L",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/cholesterol1",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "cholesterol1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-09-09T20:50:07.859+00:00",
#         "source": "#N4tTkWSdxX9GXtmn"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: cholesterol</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol <span>(Details : {LOINC code '35200-5' = 'Cholesterol [Mass or Moles/volume] in Serum or Plasma', given as 'Cholesterol [Moles/​volume] in Serum or Plasma'})</span></p><p><b>subject</b>: <a>Patient/Patient1</a></p><p><b>performer</b>: <a>Acme Laboratory, Inc</a></p><p><b>value</b>: 6.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>4.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "35200-5",
#           "display": "Cholesterol [Moles/​volume] in Serum or Plasma"
#         }, {
#           "system": "http://loinc.org",
#           "code": "35205"
#         } ],
#         "text": "Cholesterol"
#       },
#       "subject": {
#         "reference": "Patient/Patient1"
#       },
#       "performer": [ {
#         "reference": "Organization/Org1",
#         "display": "Acme Laboratory, Inc"
#       } ],
#       "valueQuantity": {
#         "value": 6.3,
#         "unit": "mmol/L",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "referenceRange": [ {
#         "high": {
#           "value": 4.5,
#           "unit": "mmol/L",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/ldlcholesterol1",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "ldlcholesterol1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-09-09T20:50:08.181+00:00",
#         "source": "#N4tTkWSdxX9GXtmn"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: ldlcholesterol</p><p><b>status</b>: final</p><p><b>code</b>: LDL Chol. (Calc) <span>(Details : {LOINC code '13457-7' = 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation', given as 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation'})</span></p><p><b>subject</b>: <a>Patient/Patient1</a></p><p><b>performer</b>: <a>Acme Laboratory, Inc</a></p><p><b>value</b>: 4.6 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>3.0 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "13457-7",
#           "display": "Cholesterol in LDL [Mass/volume] in Serum or Plasma by calculation"
#         } ],
#         "text": "LDL Chol. (Calc)"
#       },
#       "subject": {
#         "reference": "Patient/Patient1"
#       },
#       "encounter": {
#         "reference": "Encounter/Enc1"
#       },
#       "performer": [ {
#         "reference": "Organization/Org1",
#         "display": "Acme Laboratory, Inc"
#       } ],
#       "valueQuantity": {
#         "value": 4.6,
#         "unit": "mmol/L",
#         "system": "http://unitsofmeasure.org",
#         "code": "mmol/L"
#       },
#       "note": [ {
#         "text": "Note : The patient Diagnostic report"
#       } ],
#       "referenceRange": [ {
#         "high": {
#           "value": 3.0,
#           "unit": "mmol/L",
#           "system": "http://unitsofmeasure.org",
#           "code": "mmol/L"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/1838059",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "1838059",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2021-01-27T11:38:40.022+00:00",
#         "source": "#jZaF4S6RxfVluo99"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: cholesterol</p><p><b>status</b>: final</p><p><b>code</b>: Cholesterol <span>(Details : {LOINC code '35200-5' = 'Cholesterol [Mass or Moles/volume] in Serum or Plasma', given as 'Cholesterol [Moles/​volume] in Serum or Plasma'})</span></p><p><b>subject</b>: <a>Patient/pat2</a></p><p><b>performer</b>: <a>Acme Laboratory, Inc</a></p><p><b>value</b>: 6.3 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></p><h3>ReferenceRanges</h3><table><tr><td>-</td><td><b>High</b></td></tr><tr><td>*</td><td>4.5 mmol/L<span> (Details: UCUM code mmol/L = 'mmol/L')</span></td></tr></table></div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "35200-5",
#           "display": "Cholesterol [Moles/​volume] in Serum or Plasma"
#         } ],
#         "text": "Cholesterol"
#       },
#       "subject": {
#         "reference": "Patient/1835964"
#       },
#       "valueQuantity": {
#         "value": 125,
#         "unit": "mg/dL",
#         "system": "http://unitsofmeasure.org",
#         "code": "mg/dL"
#       },
#       "referenceRange": [ {
#         "low": {
#           "value": 80,
#           "unit": "mg/dL",
#           "system": "http://unitsofmeasure.org",
#           "code": "mg/dL"
#         },
#         "high": {
#           "value": 140,
#           "unit": "mg/dL",
#           "system": "http://unitsofmeasure.org",
#           "code": "mg/dL"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# alle Patienten mit Namen
req = url + "Patient?name=WienerNeustadt&_summary=count"
response = requests.request("GET", req, headers=headers)
print("Anzahl der Patienten: " + str(response.json().get('total')))

req = url + "Patient?name=WienerNeustadt"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# Anzahl der Patienten: 11
# {
#   "resourceType": "Bundle",
#   "id": "1bbac5c8-e0b6-4478-80c1-3121cf91456d",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:15.791+00:00"
#   },
#   "type": "searchset",
#   "total": 11,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?name=WienerNeustadt"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7198903",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7198903",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-13T14:21:01.360+00:00",
#         "source": "#79Y22jJNcs9cOtNc"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTFJEDR </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtFjeDR",
#         "family": "WienerNeustadtFjeDR",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/25018763",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "25018763",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-10-17T17:30:28.095+00:00",
#         "source": "#RwApzR1iERHZQO1x"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTGGIUD </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtgGiuD",
#         "family": "WienerNeustadtgGiuD",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185186",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185186",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:20:03.532+00:00",
#         "source": "#FSrA3geZ4zJlv6el"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTMZTIT </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>01 January 1950</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtMZtIT",
#         "family": "WienerNeustadtMZtIT",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "male",
#       "birthDate": "1950-01-01"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185197",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185197",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:33:01.605+00:00",
#         "source": "#2eopjhS2NavITyoA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNJRLM </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNJrLm",
#         "family": "WienerNeustadtNJrLm",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185179",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185179",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:15:00.354+00:00",
#         "source": "#j65nboUIxeTY5GJU"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNRCXC </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>01 January 1950</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNRcxC",
#         "family": "WienerNeustadtNRcxC",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "male",
#       "birthDate": "1950-01-01"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185275",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185275",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:34.390+00:00",
#         "source": "#XtNqiLTeSWGWWGGj"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNWUZL </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNWuZl",
#         "family": "WienerNeustadtNWuZl",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185274",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185274",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:24.704+00:00",
#         "source": "#2lmdbIo15meQh68T"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTOGHDE </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtOgHDe",
#         "family": "WienerNeustadtOgHDe",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185301",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185301",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T19:36:45.546+00:00",
#         "source": "#OReKzjEcNwhrt9n6"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTQGEHT </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtQGeHt",
#         "family": "WienerNeustadtQGeHt",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/25018760",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "25018760",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-10-17T17:29:32.057+00:00",
#         "source": "#9offEdeMZgcV0uU8"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTRCFHG </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtRcFHg",
#         "family": "WienerNeustadtRcFHg",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185176",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185176",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:13:28.232+00:00",
#         "source": "#xn4GjWWNOR2lSw6D"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTRUERJ </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>01 January 1950</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtRUerj",
#         "family": "WienerNeustadtRUerj",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "male",
#       "birthDate": "1950-01-01"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185273",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185273",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:21.234+00:00",
#         "source": "#9Grm3F5PtjTzLfMh"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTZCATK </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtzcaTk",
#         "family": "WienerNeustadtzcaTk",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Anzahl der Patienten
req = url + "Patient?_summary=count"
response = requests.request("GET", req, headers=headers)
print("Anzahl der Patienten: " + str(response.json().get('total')))
print(response.text)
# Out:
# Anzahl der Patienten: 631372
# {
#   "resourceType": "Bundle",
#   "id": "12e66581-4f8d-41a2-b236-d8f0d8b2267e",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:16.789+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "total": 631372
# }

# %%
# Anzahl der Patienten
req = url + "Patient?_total=accurate"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "700a24f5-bfe5-4cb8-9acb-dd1d3b82fb96",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:19.361+00:00"
#   },
#   "type": "searchset",
#   "total": 631372,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?_total=accurate"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=700a24f5-bfe5-4cb8-9acb-dd1d3b82fb96&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592759",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592759",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-27T22:46:51.355+00:00",
#         "source": "#g1xL6lUWd8NwMgKj"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Mr Khan <b>MOAZZAM </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>123456789</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "system": "https://fhir.infoway-inforoute.ca/NamingSystem/ca-ab-moh-patient-id",
#         "value": "123456789"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Moazzam",
#         "given": [ "Khan" ],
#         "prefix": [ "Mr" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592760",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592760",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-27T22:50:54.357+00:00",
#         "source": "#DjXyXcrzc9Dnq4fY"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Mr Khan <b>MOAZZAM </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>123456789</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "system": "https://fhir.infoway-inforoute.ca/NamingSystem/ca-ab-moh-patient-id",
#         "value": "123456789"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Moazzam",
#         "given": [ "Khan" ],
#         "prefix": [ "Mr" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592761",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592761",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T00:08:44.607+00:00",
#         "source": "#Q1nC892XplNWyz8W"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">THERESA <b>STOKES </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>4039945981744</td></tr><tr><td>Address</td><td><span>11 MAN STREET </span><br/><span>BROOKHAVEN </span><span>PA </span></td></tr><tr><td>Date of birth</td><td><span>08 November 1938</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ]
#         },
#         "value": "4039945981744"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SB",
#             "display": "Social Security Number"
#           } ]
#         },
#         "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#         "value": "124686652"
#       } ],
#       "name": [ {
#         "use": "official",
#         "text": "THERESA STOKES",
#         "family": "STOKES",
#         "given": [ "THERESA" ]
#       } ],
#       "gender": "other",
#       "birthDate": "1938-11-08",
#       "deceasedBoolean": false,
#       "address": [ {
#         "use": "temp",
#         "text": "11 MAN STREET  BROOKHAVEN PA 19015",
#         "line": [ "11 MAN STREET" ],
#         "city": "BROOKHAVEN",
#         "district": "001",
#         "state": "PA",
#         "postalCode": "19015"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "S"
#         } ]
#       },
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:oid:2.16.840.1.113883.4.642.3.891",
#             "code": "OTH"
#           } ]
#         }
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592766",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592766",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T01:32:19.930+00:00",
#         "source": "#ZXMGaKdg7ZmmzkGB",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n            <p>Anderson,David (Male 64y)</p>\n        </div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org.au/fhir/StructureDefinition/indigenous-status",
#         "valueCoding": {
#           "system": "https://healthterminologies.gov.au/fhir/CodeSystem/australian-indigenous-status-1",
#           "code": "4",
#           "display": "Neither Aboriginal nor Torres Strait Islander origin"
#         }
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "country": "NZ"
#         }
#       } ],
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "extension": [ {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-status-1",
#             "code": "active",
#             "display": "active"
#           }
#         }, {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-record-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-record-status-1",
#             "code": "verified",
#             "display": "verified"
#           }
#         } ],
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/iso21090-preferred",
#           "valueBoolean": true
#         } ],
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "U",
#           "display": "unmarried"
#         } ],
#         "text": "Single"
#       },
#       "contact": [ {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Rubble",
#           "given": [ "Wilma" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "phone",
#           "value": "(555) 555 555"
#         } ]
#       }, {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         }, {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "N"
#           }, {
#             "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
#             "code": "CHILD"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Anderson",
#           "given": [ "Penny" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "email",
#           "value": "anderson.p@hcn.samplesdb.com.au",
#           "use": "home"
#         }, {
#           "system": "phone",
#           "value": "(666) 666 666"
#         } ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592768",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592768",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T01:45:49.132+00:00",
#         "source": "#fEPN9iEZW7PJGK5g",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n            <p>Anderson,David (Male 64y)</p>\n        </div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org.au/fhir/StructureDefinition/indigenous-status",
#         "valueCoding": {
#           "system": "https://healthterminologies.gov.au/fhir/CodeSystem/australian-indigenous-status-1",
#           "code": "4",
#           "display": "Neither Aboriginal nor Torres Strait Islander origin"
#         }
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "country": "NZ"
#         }
#       } ],
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "extension": [ {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-status-1",
#             "code": "active",
#             "display": "active"
#           }
#         }, {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-record-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-record-status-1",
#             "code": "verified",
#             "display": "verified"
#           }
#         } ],
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/iso21090-preferred",
#           "valueBoolean": true
#         } ],
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "U",
#           "display": "unmarried"
#         } ],
#         "text": "Single"
#       },
#       "contact": [ {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Rubble",
#           "given": [ "Wilma" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "phone",
#           "value": "(555) 555 555"
#         } ]
#       }, {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         }, {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "N"
#           }, {
#             "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
#             "code": "CHILD"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Anderson",
#           "given": [ "Penny" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "email",
#           "value": "anderson.p@hcn.samplesdb.com.au",
#           "use": "home"
#         }, {
#           "system": "phone",
#           "value": "(666) 666 666"
#         } ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592765",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592765",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2020-01-28T02:18:55.560+00:00",
#         "source": "#oiQu4lB7EWAzXnmf",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n            <p>Anderson,David (Male 64y)</p>\n        </div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org.au/fhir/StructureDefinition/indigenous-status",
#         "valueCoding": {
#           "system": "https://healthterminologies.gov.au/fhir/CodeSystem/australian-indigenous-status-1",
#           "code": "4",
#           "display": "Neither Aboriginal nor Torres Strait Islander origin"
#         }
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "country": "NZ"
#         }
#       } ],
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "extension": [ {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-status-1",
#             "code": "active",
#             "display": "active"
#           }
#         }, {
#           "url": "http://hl7.org.au/fhir/StructureDefinition/ihi-record-status",
#           "valueCoding": {
#             "system": "https://healthterminologies.gov.au/fhir/CodeSystem/ihi-record-status-1",
#             "code": "verified",
#             "display": "verified"
#           }
#         } ],
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/iso21090-preferred",
#           "valueBoolean": true
#         } ],
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "U",
#           "display": "unmarried"
#         } ],
#         "text": "Single"
#       },
#       "contact": [ {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Rubble",
#           "given": [ "Wilma" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "phone",
#           "value": "(555) 555 555"
#         } ]
#       }, {
#         "relationship": [ {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "C"
#           } ]
#         }, {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0131",
#             "code": "N"
#           }, {
#             "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
#             "code": "CHILD"
#           } ]
#         } ],
#         "name": {
#           "use": "usual",
#           "family": "Anderson",
#           "given": [ "Penny" ],
#           "prefix": [ "Mrs" ]
#         },
#         "telecom": [ {
#           "system": "email",
#           "value": "anderson.p@hcn.samplesdb.com.au",
#           "use": "home"
#         }, {
#           "system": "phone",
#           "value": "(666) 666 666 0000"
#         } ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592772",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592772",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:12.913+00:00",
#         "source": "#yBJCDs3YGlUsOefV"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>34ee3a74-8dc1-449d-a543-3d854e516783</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "34ee3a74-8dc1-449d-a543-3d854e516783"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592773",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592773",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:13.451+00:00",
#         "source": "#Z51sAVzUAYuAiqf4"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>9d83794c-0020-4c01-8e1c-c183d7a7b1f6</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "9d83794c-0020-4c01-8e1c-c183d7a7b1f6"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592784",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592784",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:15.865+00:00",
#         "source": "#J5R7BvP3eHOuiW52"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>9d0ba820-1780-4999-92d5-2e402e8b1f21</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "9d0ba820-1780-4999-92d5-2e402e8b1f21"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592785",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592785",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.013+00:00",
#         "source": "#vaVZAvj7UBGsmAut"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>f910fd2c-99d0-43b9-9358-4715a44799e3</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "f910fd2c-99d0-43b9-9358-4715a44799e3"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592792",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592792",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.737+00:00",
#         "source": "#SBxpE0Mz9aX3GVzM"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>5bc5124c-e0e4-4071-aa9b-a2a0cc5b39b0</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "5bc5124c-e0e4-4071-aa9b-a2a0cc5b39b0"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592793",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592793",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.843+00:00",
#         "source": "#Bjs8Xzzw6gz9dxGS"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>eaf7ef70-8a5c-4496-8ead-fd384d5fc7c2</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "eaf7ef70-8a5c-4496-8ead-fd384d5fc7c2"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592800",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592800",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:19.634+00:00",
#         "source": "#waoyfKrXR85Wimq2"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>5f4119fb-0514-4029-96a0-650980c562ef</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "5f4119fb-0514-4029-96a0-650980c562ef"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592801",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592801",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:19.733+00:00",
#         "source": "#gRhxB4yx3Aj6YIi3"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>e7a8ed5a-ebb6-467a-8108-64a69a73ecff</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "e7a8ed5a-ebb6-467a-8108-64a69a73ecff"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592808",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592808",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:20.390+00:00",
#         "source": "#Gi3P6AGyHfok0HSL"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>8be2b49c-3413-4fa2-bf56-4730fd6ef9d1</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "8be2b49c-3413-4fa2-bf56-4730fd6ef9d1"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592809",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592809",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:20.491+00:00",
#         "source": "#rjNfCWsg7vH5odar"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>70beaf90-3e11-4199-998e-e29ea138910f</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "70beaf90-3e11-4199-998e-e29ea138910f"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592816",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592816",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.146+00:00",
#         "source": "#hNPM4aMBhuabey0f"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>7c2fa9c9-e364-4ee3-ba04-c0945414e42b</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "7c2fa9c9-e364-4ee3-ba04-c0945414e42b"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592817",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592817",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.264+00:00",
#         "source": "#jbe7dKDImuZg5Ex6"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>76bf215f-cb02-4a12-8d2a-bacadbcce262</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "76bf215f-cb02-4a12-8d2a-bacadbcce262"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592824",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592824",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.850+00:00",
#         "source": "#o6YkvrENabFOheNm"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Bob <b>ALEXANDER </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>afb93b5c-47d3-4722-9bb8-f063499a6835</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "afb93b5c-47d3-4722-9bb8-f063499a6835"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592825",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592825",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.964+00:00",
#         "source": "#2vHqWkiMMyX2QhZf"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Caleb <b>CUSHING </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>a11a0585-1567-4a2b-b4e1-350fe12f6d40</td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "a11a0585-1567-4a2b-b4e1-350fe12f6d40"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Rückgabe von Summary-Paramtern einer Ressource (idF. Patient)
req = url + "Patient?_summary=true"
# Rückgabe von ausgewählten Attributen einer Ressource (idF. Ressource Patient mit den Attributen id und gender)
#req = url + "Patient?_elements=id,gender"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "9a288049-9b36-4031-9ca4-15b0a6251735",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:20.586+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?_summary=true"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=9a288049-9b36-4031-9ca4-15b0a6251735&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592759",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592759",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-27T22:46:51.355+00:00",
#         "source": "#g1xL6lUWd8NwMgKj",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "system": "https://fhir.infoway-inforoute.ca/NamingSystem/ca-ab-moh-patient-id",
#         "value": "123456789"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Moazzam",
#         "given": [ "Khan" ],
#         "prefix": [ "Mr" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592760",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592760",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-27T22:50:54.357+00:00",
#         "source": "#DjXyXcrzc9Dnq4fY",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "system": "https://fhir.infoway-inforoute.ca/NamingSystem/ca-ab-moh-patient-id",
#         "value": "123456789"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Moazzam",
#         "given": [ "Khan" ],
#         "prefix": [ "Mr" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592761",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592761",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T00:08:44.607+00:00",
#         "source": "#Q1nC892XplNWyz8W",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ]
#         },
#         "value": "4039945981744"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SB",
#             "display": "Social Security Number"
#           } ]
#         },
#         "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#         "value": "124686652"
#       } ],
#       "name": [ {
#         "use": "official",
#         "text": "THERESA STOKES",
#         "family": "STOKES",
#         "given": [ "THERESA" ]
#       } ],
#       "gender": "other",
#       "birthDate": "1938-11-08",
#       "deceasedBoolean": false,
#       "address": [ {
#         "use": "temp",
#         "text": "11 MAN STREET  BROOKHAVEN PA 19015",
#         "line": [ "11 MAN STREET" ],
#         "city": "BROOKHAVEN",
#         "district": "001",
#         "state": "PA",
#         "postalCode": "19015"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592766",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592766",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T01:32:19.930+00:00",
#         "source": "#ZXMGaKdg7ZmmzkGB",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ],
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592768",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592768",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T01:45:49.132+00:00",
#         "source": "#fEPN9iEZW7PJGK5g",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ],
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592765",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592765",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2020-01-28T02:18:55.560+00:00",
#         "source": "#oiQu4lB7EWAzXnmf",
#         "profile": [ "https://aehrc.com/fhir/StructureDefinition/AUPrimaryCarePatient" ],
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MC",
#             "display": "Patient's Medicare Number"
#           } ],
#           "text": "Medicare Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/medicare-number",
#         "value": "62882534431",
#         "period": {
#           "end": "2021-07"
#         }
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PEN",
#             "display": "Pension Number"
#           } ],
#           "text": "Pensioner Concession Card Number"
#         },
#         "system": "http://ns.electronichealth.net.au/id/centrelink-customer-reference-number",
#         "value": "403123456H"
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NI",
#             "display": "National unique individual identifier"
#           } ],
#           "text": "IHI"
#         },
#         "system": "http://ns.electronichealth.net.au/id/hi/ihi/1.0",
#         "value": "8003608166845602",
#         "period": {
#           "start": "2018-08-17T19:35:04+10:00"
#         }
#       }, {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MB",
#             "display": "Member Number"
#           } ],
#           "text": "Private Health Insurance Member Number"
#         },
#         "value": "21342233J",
#         "assigner": {
#           "display": "MEDIBANK PRIVATE LTD"
#         }
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "usual",
#         "family": "Anderson",
#         "given": [ "David" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "David"
#       } ],
#       "telecom": [ {
#         "system": "email",
#         "value": "anderson.p@hcn.samplesdb.com.au",
#         "use": "home"
#       }, {
#         "system": "phone",
#         "value": "(07) 3124 5678"
#       } ],
#       "gender": "male",
#       "birthDate": "1955-01-04",
#       "deceasedBoolean": false,
#       "address": [ {
#         "use": "home",
#         "type": "physical",
#         "line": [ "61 Wallace Street" ],
#         "city": "Bundaberg",
#         "state": "QLD",
#         "postalCode": "4670"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592772",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592772",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:12.913+00:00",
#         "source": "#yBJCDs3YGlUsOefV",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "34ee3a74-8dc1-449d-a543-3d854e516783"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592773",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592773",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:13.451+00:00",
#         "source": "#Z51sAVzUAYuAiqf4",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "9d83794c-0020-4c01-8e1c-c183d7a7b1f6"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592784",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592784",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:15.865+00:00",
#         "source": "#J5R7BvP3eHOuiW52",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "9d0ba820-1780-4999-92d5-2e402e8b1f21"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592785",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592785",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.013+00:00",
#         "source": "#vaVZAvj7UBGsmAut",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "f910fd2c-99d0-43b9-9358-4715a44799e3"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592792",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592792",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.737+00:00",
#         "source": "#SBxpE0Mz9aX3GVzM",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "5bc5124c-e0e4-4071-aa9b-a2a0cc5b39b0"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592793",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592793",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:16.843+00:00",
#         "source": "#Bjs8Xzzw6gz9dxGS",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "eaf7ef70-8a5c-4496-8ead-fd384d5fc7c2"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592800",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592800",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:19.634+00:00",
#         "source": "#waoyfKrXR85Wimq2",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "5f4119fb-0514-4029-96a0-650980c562ef"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592801",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592801",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:19.733+00:00",
#         "source": "#gRhxB4yx3Aj6YIi3",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "e7a8ed5a-ebb6-467a-8108-64a69a73ecff"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592808",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592808",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:20.390+00:00",
#         "source": "#Gi3P6AGyHfok0HSL",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "8be2b49c-3413-4fa2-bf56-4730fd6ef9d1"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592809",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592809",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:20.491+00:00",
#         "source": "#rjNfCWsg7vH5odar",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "70beaf90-3e11-4199-998e-e29ea138910f"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592816",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592816",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.146+00:00",
#         "source": "#hNPM4aMBhuabey0f",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "7c2fa9c9-e364-4ee3-ba04-c0945414e42b"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592817",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592817",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.264+00:00",
#         "source": "#jbe7dKDImuZg5Ex6",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "76bf215f-cb02-4a12-8d2a-bacadbcce262"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592824",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592824",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.850+00:00",
#         "source": "#o6YkvrENabFOheNm",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "afb93b5c-47d3-4722-9bb8-f063499a6835"
#       } ],
#       "name": [ {
#         "family": "Alexander",
#         "given": [ "Bob" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/592825",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "592825",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-01-28T05:31:21.964+00:00",
#         "source": "#2vHqWkiMMyX2QhZf",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://hl7.org/fhir/v2/0203",
#             "code": "MR"
#           } ]
#         },
#         "value": "a11a0585-1567-4a2b-b4e1-350fe12f6d40"
#       } ],
#       "name": [ {
#         "family": "Cushing",
#         "given": [ "Caleb" ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Anzahl der Patienten ohne GebDat
req = url + "Patient?birthdate:missing&_summary=count"

#Anzahl der Patienten mit Sterbekennzeichen
#req = url + "Patient?deceased:true&_summary=count"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "50481d70-8e2d-4ff8-83b7-f6c8636e9c0f",
#   "meta": {
#     "lastUpdated": "2023-10-21T22:36:21.587+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "total": 428004
# }

# %%
# Anzahl der Geschlechter und Abfragedauer
req = url + "Patient" + '?' + 'gender=male' + '&' + '_summary=count'
response = requests.request("GET", req, headers=headers)
print("male: " + str(response.json().get('total')) + " (" + str(response.elapsed.total_seconds()) + ' s)')
req = url + "Patient" + '?' + 'gender=female' + '&' + '_summary=count'
response = requests.request("GET", req, headers=headers)
print("female: " + str(response.json().get('total')) + " (" + str(response.elapsed.total_seconds()) + ' s)')
req = url + "Patient" + '?' + 'gender:missing=true' + '&' + '_summary=count'
response = requests.request("GET", req, headers=headers)
print("missing: " + str(response.json().get('total')) + " (" + str(response.elapsed.total_seconds()) + ' s)')
# Out:
# male: 223960 (2.53003 s)
# female: 133327 (0.918344 s)
# missing: None (20.476972 s)

# %%
# String Search
req = url + 'Patient' + '?' + 'family=Koll' + '&_elements=name'
#req = url + 'Patient' + '?' + 'family:exact=MrXXX' + '&_elements=name'
#req = url + 'Patient' + '?' + 'family:contains=Mr' + '&_elements=name'
response = requests.request("GET", req, headers=headers)
#print(response.text)

for entry in response.json().get('entry'):
    resource = entry.get('resource')
    print(resource.get('id'), end=': ')
    print(', '.join(map(lambda n: n.get('family'), resource.get('name'))))
# Out:
# 2376392: Kölle
# 1709914: Kollege
# 7167994: Koller
# 7170339: Koller
# 7162763: Kolli
# 7162765: Kolli
# 7162767: Kolli
# 7162769: Kolli
# 7162771: Kolli
# 7162773: Kolli
# 7162777: Kolli
# 7162779: Kolli
# 7162781: Kolli
# 7162783: Kolli
# 7162785: Kolli
# 7162787: Kolli
# 7162789: Kolli
# 7162915: Kolli
# 7163145: Kolli
# 7163147: Kolli

# %%
IFrame('https://www.hl7.org/fhir/search.html#prefix', width=1200, height=500)
# Out:
#         <iframe
#             width="1200"
#             height="500"
#             src="https://www.hl7.org/fhir/search.html#prefix"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Date Search
# date searches support lt(<), le(<=), gt(>), ge(>=), sa(starts after), and eb(ends before) "prefixes"

# Patienten mit Geburtsjahr
#req = url + 'Patient' + '?' + 'birthdate=1984'

# Patienten mit Geburtstag zwischen zwei Zeitpunkten
req = url + 'Patient?birthdate=gt2016-01-01&birthdate=lt2019-01-01'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "2e832ada-e3a6-463c-90bf-215579f402d2",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:38.055+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?birthdate=gt2016-01-01&birthdate=lt2019-01-01"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=2e832ada-e3a6-463c-90bf-215579f402d2&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727761",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727761",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:21.487+00:00",
#         "source": "#fJnbOVkf30U4fL52"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pollt4fi44dl</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pollt4fi44dl"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727762",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727762",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:31.914+00:00",
#         "source": "#8S3blBoKvmyy1wi3"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Psnryzb16jdh</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Psnryzb16jdh"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727763",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727763",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:33.948+00:00",
#         "source": "#WEEbvd1Ru0ElhpWr"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pkolczhc0hmr</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pkolczhc0hmr"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727764",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727764",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:35.133+00:00",
#         "source": "#DjYYLglI2rxlbtRC"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pfvqzko1lzt</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pfvqzko1lzt"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727765",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727765",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:35.774+00:00",
#         "source": "#KE7BJ3vFhrAUgUz7"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>P7kb8m3htb0v</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "P7kb8m3htb0v"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727766",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727766",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:36.055+00:00",
#         "source": "#tW4XNfJk7sIgbArG"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pe3n1uwj3oe6</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pe3n1uwj3oe6"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727767",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727767",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:36.315+00:00",
#         "source": "#Ai0cCIMMSBJfdc1F"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pg0fe07bopz5</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pg0fe07bopz5"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727768",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727768",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:36.509+00:00",
#         "source": "#19svMWKmlxUI65T2"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pm6qr1vdvb2</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pm6qr1vdvb2"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727769",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727769",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:36.601+00:00",
#         "source": "#T1yQOfT4on03QBVT"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pgew3uc2hunu</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pgew3uc2hunu"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727770",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727770",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:36.791+00:00",
#         "source": "#kYFnr8hpsPUDawO6"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pjqv3629hvx</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pjqv3629hvx"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727771",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727771",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:37.280+00:00",
#         "source": "#RnSaWBXw7106uCqX"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>P15ie2d93oqs</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "P15ie2d93oqs"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727772",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727772",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:37.375+00:00",
#         "source": "#tLnRhGGlfbIqwGNL"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Piyvjz7sbwzp</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Piyvjz7sbwzp"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727773",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727773",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:37.463+00:00",
#         "source": "#OAEsK2TJyjTFIRd1"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pg8a2g8vubjd</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pg8a2g8vubjd"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727774",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727774",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:37.760+00:00",
#         "source": "#pABELT0cJ5KOX0K5"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pxza1i68dt</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pxza1i68dt"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727775",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727775",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:37.975+00:00",
#         "source": "#HnmP6RM1eIw2ytrY"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Pio542uuabx</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Pio542uuabx"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727776",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727776",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:38.141+00:00",
#         "source": "#iqFFUsbDgp8P25TI"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>P598phdnnxy</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "P598phdnnxy"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727777",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727777",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:38.360+00:00",
#         "source": "#v9ZOilDgWfiQrYhr"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Ptvn2zjm8ug</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Ptvn2zjm8ug"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727778",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727778",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:38.641+00:00",
#         "source": "#3zIw6OhcMvmDCnQf"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>P7p67b1k5d9f</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "P7p67b1k5d9f"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727779",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727779",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:38.861+00:00",
#         "source": "#xCKVkKtIMa2Jj7q6"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>P3tbbb7cocp8</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "P3tbbb7cocp8"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1727780",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1727780",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-01-05T13:00:38.975+00:00",
#         "source": "#qqSVSTJTapKWgjpd"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Test Name </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>Plhm5cufz7u</td></tr><tr><td>Date of birth</td><td><span>03 January 2016</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "system": "mrn-tenant1",
#         "value": "Plhm5cufz7u"
#       } ],
#       "active": true,
#       "name": [ {
#         "given": [ "Test Name" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "+918147910531",
#         "use": "mobile",
#         "rank": 1
#       }, {
#         "system": "email",
#         "value": "test@gmail.com",
#         "use": "work",
#         "rank": 2
#       } ],
#       "gender": "male",
#       "birthDate": "2016-01-03",
#       "_birthDate": {
#         "extension": [ {
#           "url": "estimated-birthDate",
#           "valueBoolean": true
#         } ]
#       },
#       "deceasedBoolean": false,
#       "photo": [ {
#         "contentType": "image/png",
#         "data": ""
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
IFrame('https://build.fhir.org/observation.html#search', width=1200, height=500)
# Out:
#         <iframe
#             width="1200"
#             height="500"
#             src="https://build.fhir.org/observation.html#search"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Range Search

code = "8867-4"

req = url + "/Observation?code=" + code + "&value-quantity=ge50&value-quantity=le200"
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "83a9cf3d-433e-4fbc-afd7-c9a5b9525b71",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:39.846+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Observation?code=8867-4&value-quantity=ge50&value-quantity=le200"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=83a9cf3d-433e-4fbc-afd7-c9a5b9525b71&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/30195",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "30195",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-09-26T14:34:43.313+00:00",
#         "source": "#d0126f9b8578248b"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 78 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/30163"
#       },
#       "effectiveDateTime": "2019-09-19T16:34:42+02:00",
#       "valueQuantity": {
#         "value": 78,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/30190",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "30190",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-09-26T14:34:43.313+00:00",
#         "source": "#d0126f9b8578248b"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 73 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/30163"
#       },
#       "effectiveDateTime": "2019-09-26T16:34:42+02:00",
#       "valueQuantity": {
#         "value": 73,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/30200",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "30200",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-09-26T14:34:43.313+00:00",
#         "source": "#d0126f9b8578248b"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 72 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/30163"
#       },
#       "effectiveDateTime": "2019-09-12T16:34:42+02:00",
#       "valueQuantity": {
#         "value": 72,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/30210",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "30210",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-09-26T14:34:43.313+00:00",
#         "source": "#d0126f9b8578248b"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 83 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/30163"
#       },
#       "effectiveDateTime": "2019-08-29T16:34:42+02:00",
#       "valueQuantity": {
#         "value": 83,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/42053",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "42053",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-09T22:44:04.703+00:00",
#         "source": "#63743f445b69d6b2"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 72 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/42024"
#       },
#       "effectiveDateTime": "2019-10-02T15:44:04-07:00",
#       "valueQuantity": {
#         "value": 72,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/42058",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "42058",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-09T22:44:04.703+00:00",
#         "source": "#63743f445b69d6b2"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 74 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/42024"
#       },
#       "effectiveDateTime": "2019-09-25T15:44:04-07:00",
#       "valueQuantity": {
#         "value": 74,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/45681",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "45681",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-11T16:30:23.603+00:00",
#         "source": "#6b20b5c646498826"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 70 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/45657"
#       },
#       "effectiveDateTime": "2019-10-11T09:30:22-07:00",
#       "valueQuantity": {
#         "value": 70,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/45691",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "45691",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-11T16:30:23.603+00:00",
#         "source": "#6b20b5c646498826"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 76 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/45657"
#       },
#       "effectiveDateTime": "2019-09-27T09:30:22-07:00",
#       "valueQuantity": {
#         "value": 76,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/45706",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "45706",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-11T16:30:23.603+00:00",
#         "source": "#6b20b5c646498826"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 76 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/45657"
#       },
#       "effectiveDateTime": "2019-09-06T09:30:22-07:00",
#       "valueQuantity": {
#         "value": 76,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/59559",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "59559",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-12T14:26:59.026+00:00",
#         "source": "#jVDs4pAMcUUc1In9"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 72 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/59530"
#       },
#       "effectiveDateTime": "2019-11-05T15:26:58+01:00",
#       "valueQuantity": {
#         "value": 72,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/59569",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "59569",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-12T14:26:59.026+00:00",
#         "source": "#jVDs4pAMcUUc1In9"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 80 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/59530"
#       },
#       "effectiveDateTime": "2019-10-22T15:26:58+02:00",
#       "valueQuantity": {
#         "value": 80,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/69084",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "69084",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-16T16:51:50.138+00:00",
#         "source": "#Zqbl2BM5kqjpL0zz"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 83 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/69050"
#       },
#       "effectiveDateTime": "2019-11-02T10:51:50-05:00",
#       "valueQuantity": {
#         "value": 83,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/69094",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "69094",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-16T16:51:50.138+00:00",
#         "source": "#Zqbl2BM5kqjpL0zz"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 72 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/69050"
#       },
#       "effectiveDateTime": "2019-10-19T10:51:50-05:00",
#       "valueQuantity": {
#         "value": 72,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/102787",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "102787",
#       "meta": {
#         "versionId": "3",
#         "lastUpdated": "2019-11-27T13:21:49.964+00:00",
#         "source": "#z3C0uTSOZLPicVza"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "85353-1",
#           "display": "Vital signs, weight, height, head circumference, oxygen saturation and BMI panel"
#         }, {
#           "system": "http://loinc.org",
#           "code": "8867-4",
#           "display": "Heart rate"
#         } ],
#         "text": "Heart rate"
#       },
#       "subject": {
#         "reference": "Patient/1201"
#       },
#       "performer": [ {
#         "reference": "Organization/1621",
#         "display": "CAPE COD HOSPITAL"
#       } ],
#       "valueQuantity": {
#         "value": 72,
#         "unit": "beats/minute",
#         "system": "http://unitsofmeasure.org",
#         "code": "/min"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/30205",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "30205",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-09-26T14:34:43.313+00:00",
#         "source": "#d0126f9b8578248b"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 84 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/30163"
#       },
#       "effectiveDateTime": "2019-09-05T16:34:42+02:00",
#       "valueQuantity": {
#         "value": 84,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/42063",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "42063",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-09T22:44:04.703+00:00",
#         "source": "#63743f445b69d6b2"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 84 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/42024"
#       },
#       "effectiveDateTime": "2019-09-18T15:44:04-07:00",
#       "valueQuantity": {
#         "value": 84,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/45686",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "45686",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-11T16:30:23.603+00:00",
#         "source": "#6b20b5c646498826"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 75 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/45657"
#       },
#       "effectiveDateTime": "2019-10-04T09:30:22-07:00",
#       "valueQuantity": {
#         "value": 75,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/45701",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "45701",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-10-11T16:30:23.603+00:00",
#         "source": "#6b20b5c646498826"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 75 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/45657"
#       },
#       "effectiveDateTime": "2019-09-13T09:30:22-07:00",
#       "valueQuantity": {
#         "value": 75,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/59554",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "59554",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-12T14:26:59.026+00:00",
#         "source": "#jVDs4pAMcUUc1In9"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 75 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/59530"
#       },
#       "effectiveDateTime": "2019-11-12T15:26:58+01:00",
#       "valueQuantity": {
#         "value": 75,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Observation/59574",
#     "resource": {
#       "resourceType": "Observation",
#       "id": "59574",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2019-11-12T14:26:59.026+00:00",
#         "source": "#jVDs4pAMcUUc1In9"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Heart Rate, 79 bpm</div>"
#       },
#       "status": "final",
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "8867-4"
#         } ],
#         "text": "Heart Rate"
#       },
#       "subject": {
#         "reference": "Patient/59530"
#       },
#       "effectiveDateTime": "2019-10-15T15:26:58+02:00",
#       "valueQuantity": {
#         "value": 79,
#         "unit": "bpm"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Reference search
# Alle Patienten zurückgeben, die einen GP haben und den Namen/ Org des GP

req = url + 'Patient?general-practitioner:missing=false&_elements=id,name,generalPractitioner,managingOrganization'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "fad2b1a7-5c77-440d-b3a4-d05680db73ed",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:41.940+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?_elements=id%2Cname%2CgeneralPractitioner%2CmanagingOrganization&general-practitioner%3Amissing=false"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=fad2b1a7-5c77-440d-b3a4-d05680db73ed&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset&_elements=generalPractitioner,id,managingOrganization,name"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7197634",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7197634",
#       "meta": {
#         "versionId": "6",
#         "lastUpdated": "2022-12-13T10:22:29.468+00:00",
#         "source": "#TQmmEai6yV349iEo",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "use": "official",
#         "family": "Ganesan",
#         "given": [ "Karthikeyan" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/7198554"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/7197582"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7188872",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7188872",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-08T02:48:46.487+00:00",
#         "source": "#u01L2o34aMi7oSLP",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "use": "official",
#         "family": "Smith",
#         "given": [ "Jill" ],
#         "prefix": [ "Mrs" ]
#       }, {
#         "use": "maiden",
#         "family": "Windsor",
#         "given": [ "Min updated the name" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/7188843",
#         "display": "Dr Peter Gill"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7188841",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7188841",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-12-08T01:45:00.657+00:00",
#         "source": "#TxCuPYs0uK6hgNdI",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "use": "official",
#         "family": "Smith",
#         "given": [ "Jill" ],
#         "prefix": [ "Mrs" ]
#       }, {
#         "use": "maiden",
#         "family": "Windsor",
#         "given": [ "Jill" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/7188843",
#         "display": "Dr Peter Gill"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185365",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185365",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:12:50.431+00:00",
#         "source": "#3Rrk2m48iZdXnWLr",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Patrol",
#         "given": [ "Ryder" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185364",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185364",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:12:21.336+00:00",
#         "source": "#GRdBSZEO2phMA15V",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Wild",
#         "given": [ "Hilde" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185361",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185361",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:11:56.964+00:00",
#         "source": "#mmKeieMNMY8A4VcR",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Mump",
#         "given": [ "Monald" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185360",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185360",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:11:32.797+00:00",
#         "source": "#moD6p7xWWicfQJij",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "März",
#         "given": [ "Fritze" ],
#         "suffix": [ "Dr." ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185359",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185359",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:11:04.401+00:00",
#         "source": "#nMuyg4Fmx9cKYCJz",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Wietong",
#         "given": [ "Louis" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185358",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185358",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:10:43.835+00:00",
#         "source": "#BUxPbiYl8BLHEojx",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Columber",
#         "given": [ "Christoph" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185357",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185357",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:10:16.755+00:00",
#         "source": "#Ld7ck6fk2e4XGFM2",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Besenfein",
#         "given": [ "Berta" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185356",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185356",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:09:51.228+00:00",
#         "source": "#tGKG6Q8k4PznoQrJ",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Abendroth",
#         "given": [ "Anna" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185354",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185354",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:09:22.301+00:00",
#         "source": "#NdBtHCHwnAeYfLrf",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Mümmelmann",
#         "given": [ "Max" ],
#         "suffix": [ "Dr." ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185353",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185353",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T21:07:34.002+00:00",
#         "source": "#NSAJBtwdZoalTabJ",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Müller",
#         "given": [ "Tina" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr. Annette Deiters"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/example",
#         "display": "ISO Layer 8 Klinik"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7176618",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7176618",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T16:51:55.077+00:00",
#         "source": "#8xHFTaaZnnkjIOzA",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Levin",
#         "given": [ "Henry" ],
#         "suffix": [ "The 7th" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr Adam Careful"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7176617",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7176617",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T16:51:37.997+00:00",
#         "source": "#FK1U9FdxMLLvzp65",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Levin",
#         "given": [ "Henry" ],
#         "suffix": [ "The 7th" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr Adam Careful"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7176616",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7176616",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T16:51:32.105+00:00",
#         "source": "#uIC50iNp4C6cGOFs",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Levin",
#         "given": [ "Henry" ],
#         "suffix": [ "The 7th" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr Adam Careful"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7176615",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7176615",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T16:51:26.814+00:00",
#         "source": "#EJHkTZ9uTLJ1bfd5",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Levin",
#         "given": [ "Henry" ],
#         "suffix": [ "The 7th" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr Adam Careful"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7176614",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7176614",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T16:51:18.225+00:00",
#         "source": "#86K0dCmQ5QHjkdcI",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Levin",
#         "given": [ "Henry" ],
#         "suffix": [ "The 7th" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/example",
#         "display": "Dr Adam Careful"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/AAB2F9E30CF44E039B58734D1C0598FA.1",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "AAB2F9E30CF44E039B58734D1C0598FA.1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-02T01:53:14.784+00:00",
#         "source": "#5xgFD7cw7fU4HEKx",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "use": "usual",
#         "family": "TESTER",
#         "given": [ "MARY" ],
#         "prefix": [ "Mr" ]
#       }, {
#         "use": "nickname",
#         "text": "MARY"
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Organization/AAB2F9E30CF44E039B58734D1C0598FA.2"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/AAB2F9E30CF44E039B58734D1C0598FA.2"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/012b9ab9-c840-46ee-961e-5f411fd2d81a",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "012b9ab9-c840-46ee-961e-5f411fd2d81a",
#       "meta": {
#         "versionId": "3",
#         "lastUpdated": "2022-12-01T12:23:14.919+00:00",
#         "source": "#WlRl87TFPoVC0qK8",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#           "code": "SUBSETTED",
#           "display": "Resource encoded in summary mode"
#         } ]
#       },
#       "name": [ {
#         "family": "Wachira",
#         "given": [ "Ben" ]
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/1141",
#         "display": "John Smith"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
#req = url + "Patient$export"

# %%
# Alle Conditions zu einem Patienten

req = url + 'Condition' + '?' + 'patient=' + url + '/Patient/' + patient_id + '&_elements=code'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "5610f3f8-ff1b-4a23-b11f-087f2c6d83a6",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:42.195+00:00"
#   },
#   "type": "searchset",
#   "total": 0,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Condition?_elements=code&patient=http%3A%2F%2Fhapi.fhir.org%2FbaseR4%2F%2FPatient%2F7185197"
#   } ]
# }

# %% [markdown]
# # Chained search

# %%
req = url + 'Encounter?subject:Patient.name=WienerNeustadt'
response = requests.request("GET", req, headers=headers)
print(str(response.text))
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "dab154b6-bd75-465a-bf2f-52ad53c8291f",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:46.493+00:00"
#   },
#   "type": "searchset",
#   "total": 8,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Encounter?subject%3APatient.name=WienerNeustadt"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185198",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185198",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:33:02.413+00:00",
#         "source": "#KgBioZMGvDDJVma6"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtNJrLm', 'family': 'WienerNeustadtNJrLm', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185197"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185278",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185278",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:43:56.059+00:00",
#         "source": "#ijr7ytbnk6LzvQ6J"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtNWuZl', 'family': 'WienerNeustadtNWuZl', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185275"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185180",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185180",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:15:36.798+00:00",
#         "source": "#7TfwqOYQh3288qq1"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtNRcxC', 'family': 'WienerNeustadtNRcxC', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185179"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185187",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185187",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:20:04.050+00:00",
#         "source": "#9nZE6U01xdYdDAZo"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtMZtIT', 'family': 'WienerNeustadtMZtIT', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185186"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185177",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185177",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:13:28.631+00:00",
#         "source": "#i4zSE1cPKjCPzfh8"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtRUerj', 'family': 'WienerNeustadtRUerj', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185176"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185279",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185279",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:44:25.127+00:00",
#         "source": "#ZeS97KO0eXgRo9D0"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtzcaTk', 'family': 'WienerNeustadtzcaTk', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185273"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7198904",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7198904",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-13T14:21:01.586+00:00",
#         "source": "#BqH31KPXJ9uc3RfW"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtFjeDR', 'family': 'WienerNeustadtFjeDR', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7198903"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Encounter/7185302",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "7185302",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T19:36:46.086+00:00",
#         "source": "#0cUKZ8ZdsvEys9ia"
#       },
#       "text": {
#         "status": "additional",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Encounter zum Patienten:[{'use': 'official', 'text': 'Fachhochschule WienerNeustadtQGeHt', 'family': 'WienerNeustadtQGeHt', 'given': ['Fachhochschule']}]</div>"
#       },
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "270427003",
#           "display": "Patient-initiated encounter"
#         } ]
#       } ],
#       "subject": {
#         "reference": "Patient/7185301"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
req = url + "Condition" + "?" + "subject:Patient.name=WienerNeustadt" + "&" + "code=http://hl7.org/fhir/sid/icd-10-us|E10.65" + "&" + "subject:Patient.gender=female&_summary=count"
response = requests.request("GET", req, headers=headers)
print(str(response.text))
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "6ad9cd3d-fa60-46b0-ba4a-d68e7f2909b2",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:48.819+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "total": 6
# }

# %%
req = url + 'DiagnosticReport?subject:Patient.name=Alex'
response = requests.request("GET", req, headers=headers)
print(str(response.text))
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "fa5b7090-52ac-410c-97c4-0fb3c8896e76",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:57.961+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/DiagnosticReport?subject%3APatient.name=Alex"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=fa5b7090-52ac-410c-97c4-0fb3c8896e76&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542218",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542218",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> HEMOGLOBIN A1C </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 12:50:14 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17851;3110412;63;CH;6899283.889998"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33668"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "80"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/80"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542321"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "213",
#           "display": "HEMOGLOBIN A1C"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2010-07-15T11:00:00+00:00",
#         "end": "2011-04-12T12:50:00+00:00"
#       },
#       "issued": "2011-04-12T12:50:14+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542258"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/d870f03d-c140-4c02-b10b-04d4dc91be53",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "d870f03d-c140-4c02-b10b-04d4dc91be53",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Basic Metabolic Panel </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 15 December 1986 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51990-0",
#           "display": "Basic Metabolic Panel"
#         } ],
#         "text": "Basic Metabolic Panel"
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/589ca9f4-610d-48e5-a4fc-2eb49bdda88a"
#       },
#       "effectiveDateTime": "1986-12-15T13:23:44-06:00",
#       "issued": "1986-12-15T13:23:44.843-06:00",
#       "result": [ {
#         "reference": "Observation/ddb0b79f-ee7d-4caf-bbfb-a871967b60d5",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/972446dd-4135-4618-ba95-cac420bc3c40",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/1335825b-6410-4f50-a8b3-d6f190e5e862",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/70a6b1a1-22e5-43ca-bce2-1a108485aa43",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/81748818-3114-42af-a6ac-11312629d5d8",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/242f8eef-1789-4577-9bce-dbdc35647d4f",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/4e9d329c-e906-4e16-af07-aeb7ccbc76d0",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/676f5609-9816-4663-b81b-1f067f09e344",
#         "display": "Carbon Dioxide"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/c08b8f20-429a-4810-979f-2162ec69875e",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "c08b8f20-429a-4810-979f-2162ec69875e",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:01:10.215+00:00",
#         "source": "#ijlCUFxe2RZuMum2",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 07 April 1968 01:26:46</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/a1562c58-6a5a-4986-ad56-67b081e43504"
#       },
#       "encounter": {
#         "reference": "Encounter/2d86ddf5-626a-4654-b973-275975479d6a"
#       },
#       "effectiveDateTime": "1968-04-06T19:26:46-06:00",
#       "issued": "1968-04-06T19:26:46.691-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-0000000002d0",
#         "display": "Dr. Lynwood354 Daniel959"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/a555b9a5-5a65-4719-a976-b6feaf31a4fa",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "a555b9a5-5a65-4719-a976-b6feaf31a4fa",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Comprehensive metabolic 2000 panel - Serum or Plasma </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 December 1987 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "24323-8",
#           "display": "Comprehensive metabolic 2000 panel - Serum or Plasma"
#         } ],
#         "text": "Comprehensive metabolic 2000 panel - Serum or Plasma"
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/aedc3a52-f96b-4224-93c6-fa79b21bc2b6"
#       },
#       "effectiveDateTime": "1987-12-12T13:23:44-06:00",
#       "issued": "1987-12-12T13:23:44.843-06:00",
#       "result": [ {
#         "reference": "Observation/50a3588b-01e9-47d9-b5c5-7da859a4aef5",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/6b6b12d8-aa48-42ab-9680-a8b904a0e4ee",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/bfd41f38-9db7-4c77-a36e-8ef0b4d5d678",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/c3dfb3da-168c-4e0a-ba2a-78a6e94d3f4b",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/03e6bb4f-6240-4a37-91fd-7094c94c00a7",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/b8230fda-2aed-4a03-827c-a71effa242eb",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/df6cabe0-d82c-4a73-b17b-c9fce4c48b34",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/cf913dbf-2901-417d-98ab-9aed8066d40b",
#         "display": "Carbon Dioxide"
#       }, {
#         "reference": "Observation/f307c443-203a-41a9-aeb2-b2d98988ba42",
#         "display": "Glomerular filtration rate/​1.73 sq M.predicted"
#       }, {
#         "reference": "Observation/0da590e7-0b6d-4508-b446-44ecb88b1cec",
#         "display": "Protein [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/7cdd74c8-d0d5-40d9-9c2c-f1bff21d5c7d",
#         "display": "Albumin [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/5270a78b-91f8-44a4-aa15-165adc70086a",
#         "display": "Globulin [Mass/​volume] in Serum by calculation"
#       }, {
#         "reference": "Observation/2038a74a-0a89-4e98-8e53-fa2f15e16735",
#         "display": "Bilirubin.total [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/de8989c5-1d86-4f67-961a-87dded413acd",
#         "display": "Alkaline phosphatase [Enzymatic activity/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/56a3fc0b-4eff-4fe9-8fe8-024066f9dafb",
#         "display": "Alanine aminotransferase [Enzymatic activity/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/d5f9fa84-05ce-4883-9270-0559648b8fc8",
#         "display": "Aspartate aminotransferase [Enzymatic activity/​volume] in Serum or Plasma"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/86ea459b-adba-4182-899c-5d7f13206117",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "86ea459b-adba-4182-899c-5d7f13206117",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:01:10.215+00:00",
#         "source": "#ijlCUFxe2RZuMum2",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 28 April 1968 01:26:46</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/a1562c58-6a5a-4986-ad56-67b081e43504"
#       },
#       "encounter": {
#         "reference": "Encounter/73779d3f-09e5-4b26-b214-134f5bf611cb"
#       },
#       "effectiveDateTime": "1968-04-27T19:26:46-06:00",
#       "issued": "1968-04-27T19:26:46.691-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-00000003ec06",
#         "display": "Dr. Branden904 Abshire638"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542226",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542226",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> TSH </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 12:56:27 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17858;3110412;70;CH;6909276.889996"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33675"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "116"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/116"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542335"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "226",
#           "display": "TSH"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2009-07-22T11:00:00+00:00",
#         "end": "2011-04-12T12:56:00+00:00"
#       },
#       "issued": "2011-04-12T12:56:27+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542267"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542224",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542224",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> HEMOGLOBIN A1C </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 12:54:50 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17856;3110412;68;CH;6909276.889998"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33673"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "107"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/107"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542331"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "213",
#           "display": "HEMOGLOBIN A1C"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2009-07-22T11:00:00+00:00",
#         "end": "2011-04-12T12:54:00+00:00"
#       },
#       "issued": "2011-04-12T12:54:50+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542270"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/bc304c52-c846-4d8f-a492-41081068b00b",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "bc304c52-c846-4d8f-a492-41081068b00b",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:01:10.215+00:00",
#         "source": "#ijlCUFxe2RZuMum2",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Basic Metabolic Panel </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 04 October 1968 01:26:46</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51990-0",
#           "display": "Basic Metabolic Panel"
#         } ],
#         "text": "Basic Metabolic Panel"
#       },
#       "subject": {
#         "reference": "Patient/a1562c58-6a5a-4986-ad56-67b081e43504"
#       },
#       "encounter": {
#         "reference": "Encounter/9a6c059f-4963-48cf-8e4d-c1ea441f5ab6"
#       },
#       "effectiveDateTime": "1968-10-03T20:26:46-05:00",
#       "issued": "1968-10-03T20:26:46.691-05:00",
#       "result": [ {
#         "reference": "Observation/16cf579a-8560-4b65-9f6c-531a60001583",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/e696042a-db58-4382-8896-84a9ddf14f34",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/0b7d12a2-d375-4ba6-a035-738932d38bcf",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/98b9ef29-e790-499d-b60a-dd700c4361b2",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/04bdd14f-fae6-461e-9110-66f60598108e",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/3cf1409b-76c2-4cc2-a963-24293dedf253",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/b6156677-3dd6-49d3-b81e-8cd1ffc1fb7d",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/58febe8c-7fb5-46c0-b1e9-f866aa77299a",
#         "display": "Carbon Dioxide"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/b9369750-4792-43f4-b999-ea6c03cadece",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "b9369750-4792-43f4-b999-ea6c03cadece",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Basic Metabolic Panel </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 29 November 1985 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51990-0",
#           "display": "Basic Metabolic Panel"
#         } ],
#         "text": "Basic Metabolic Panel"
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/152b1b25-3bb1-46ad-8e93-fbc9641ed8b7"
#       },
#       "effectiveDateTime": "1985-11-29T13:23:44-06:00",
#       "issued": "1985-11-29T13:23:44.843-06:00",
#       "result": [ {
#         "reference": "Observation/31f61e5a-8236-4893-b448-5f3c5e99f4ec",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/5cb3b522-ede0-469a-8ec7-6fffe61f3f95",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/201bad16-65b7-42d8-bf6a-78612b27903c",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/318919bb-fc92-44fc-b5f7-9f22ad3b885a",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/3dc7d0b7-f31c-4ad9-b288-c698471ca1a2",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/9f05cd67-cc2e-4fc7-ace2-5781f0837072",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/dc3b8272-6613-4f4e-89cb-66cf3e86f19e",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/dcb4048c-4dd3-41ec-b56e-f0cb1f63fe55",
#         "display": "Carbon Dioxide"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542219",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542219",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> LIPID PROFILE </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 12:51:08 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17852;3110412;64;CH;6899283.889997"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33669"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "86"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/86"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542322"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "1081",
#           "display": "LIPID PROFILE"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2010-07-15T11:00:00+00:00",
#         "end": "2011-04-12T12:51:00+00:00"
#       },
#       "issued": "2011-04-12T12:51:08+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542248"
#       }, {
#         "reference": "Observation/2542323"
#       }, {
#         "reference": "Observation/2542324"
#       }, {
#         "reference": "Observation/2542256"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542242",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542242",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> T4, FREE &amp; TOTAL </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 13:12:05 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17872;3110412;84;CH;6929384.839993"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33689"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "213"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/213"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542365"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "1163",
#           "display": "T4, FREE & TOTAL"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2007-06-14T16:00:00+00:00",
#         "end": "2011-04-12T13:12:00+00:00"
#       },
#       "issued": "2011-04-12T13:12:05+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542366"
#       }, {
#         "reference": "Observation/2542315"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542216",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542216",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> CHEM 7 </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 12:49:04 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17849;3110412;61;CH;6899283.89"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33666"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "74"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/74"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542316"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "375",
#           "display": "CHEM 7"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2010-07-15T11:00:00+00:00",
#         "end": "2011-04-12T12:49:00+00:00"
#       },
#       "issued": "2011-04-12T12:49:04+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542318"
#       }, {
#         "reference": "Observation/2542275"
#       }, {
#         "reference": "Observation/2542252"
#       }, {
#         "reference": "Observation/2542319"
#       }, {
#         "reference": "Observation/2542290"
#       }, {
#         "reference": "Observation/2542268"
#       }, {
#         "reference": "Observation/2542298"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/4d551f4f-a19b-4a64-a8d2-f5317a901519",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "4d551f4f-a19b-4a64-a8d2-f5317a901519",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Comprehensive metabolic 2000 panel - Serum or Plasma </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 15 December 1986 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "24323-8",
#           "display": "Comprehensive metabolic 2000 panel - Serum or Plasma"
#         } ],
#         "text": "Comprehensive metabolic 2000 panel - Serum or Plasma"
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/0287544c-0805-4174-a26c-a4381c4bf2cb"
#       },
#       "effectiveDateTime": "1986-12-15T13:23:44-06:00",
#       "issued": "1986-12-15T13:23:44.843-06:00",
#       "result": [ {
#         "reference": "Observation/c08d3327-f839-40db-a52a-c8b76ff299ff",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/6eeb47a5-bd8b-410e-a1ce-7b8087aa4466",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/98395220-39a7-4cbe-ab0e-52a4b7d48518",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/a816a926-f0f0-4a52-90cd-c69893c6d004",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/b9b5f510-3504-4359-a00e-860852a46e85",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/97fe7239-8e57-4286-bf8a-bbb7a3727035",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/638f537a-9cfe-40c0-b989-3bf8f6688f80",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/449952cc-b97d-49d3-8b86-5acc006e912f",
#         "display": "Carbon Dioxide"
#       }, {
#         "reference": "Observation/b15f9169-8d54-4789-8f5d-7c0d88e761d3",
#         "display": "Glomerular filtration rate/​1.73 sq M.predicted"
#       }, {
#         "reference": "Observation/5d085275-8087-45cb-9322-c3ef2c726788",
#         "display": "Protein [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/59ff38b0-ecfb-4267-91cf-06ab229250fc",
#         "display": "Albumin [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/d118d471-ab8a-43cf-a4eb-28e0eb1cd9b1",
#         "display": "Globulin [Mass/​volume] in Serum by calculation"
#       }, {
#         "reference": "Observation/78c9eb9d-4baf-41ac-8ce2-d727c0c19e75",
#         "display": "Bilirubin.total [Mass/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/5dbf4d98-e464-43fe-ae24-ae6fab9dcb7d",
#         "display": "Alkaline phosphatase [Enzymatic activity/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/df5cffe1-1b21-466c-8856-0a35f25b3360",
#         "display": "Alanine aminotransferase [Enzymatic activity/​volume] in Serum or Plasma"
#       }, {
#         "reference": "Observation/5acd5da9-6748-462c-b55d-71079e7af6ee",
#         "display": "Aspartate aminotransferase [Enzymatic activity/​volume] in Serum or Plasma"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/458f01dc-e19d-414f-b94f-32a899a63f88",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "458f01dc-e19d-414f-b94f-32a899a63f88",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 December 1987 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/aedc3a52-f96b-4224-93c6-fa79b21bc2b6"
#       },
#       "effectiveDateTime": "1987-12-12T13:23:44-06:00",
#       "issued": "1987-12-12T13:23:44.843-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-000000000460",
#         "display": "Dr. Marceline716 Trantow673"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/378d28af-cd06-40ac-8d07-e09bcc17d853",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "378d28af-cd06-40ac-8d07-e09bcc17d853",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-lab" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Basic Metabolic Panel </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 December 1987 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0074",
#           "code": "LAB",
#           "display": "Laboratory"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51990-0",
#           "display": "Basic Metabolic Panel"
#         } ],
#         "text": "Basic Metabolic Panel"
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/b27def9c-8dfa-4952-9ccd-78db4b9081c4"
#       },
#       "effectiveDateTime": "1987-12-12T13:23:44-06:00",
#       "issued": "1987-12-12T13:23:44.843-06:00",
#       "result": [ {
#         "reference": "Observation/5cd77cf8-96e7-4bf8-a524-36c58487be80",
#         "display": "Glucose"
#       }, {
#         "reference": "Observation/7bf4a6a6-55ea-4e23-b0fe-e29ab8c7007f",
#         "display": "Urea Nitrogen"
#       }, {
#         "reference": "Observation/2fc3274b-5685-402e-9425-7acc03f4b3a3",
#         "display": "Creatinine"
#       }, {
#         "reference": "Observation/da82b845-aef9-44a2-ba90-559dcf775a04",
#         "display": "Calcium"
#       }, {
#         "reference": "Observation/b3702db4-4998-48a2-97a4-0dc3b50b7cdd",
#         "display": "Sodium"
#       }, {
#         "reference": "Observation/122b545d-da5d-4141-8f2e-275b7a8a7eef",
#         "display": "Potassium"
#       }, {
#         "reference": "Observation/b40dc0b2-6f57-4dc7-b8ba-baf09e404bb7",
#         "display": "Chloride"
#       }, {
#         "reference": "Observation/11fa1584-4a09-451f-ac64-0ee62cedeb1b",
#         "display": "Carbon Dioxide"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/1e9cc9cb-4e50-4272-9174-3996c1b2b270",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "1e9cc9cb-4e50-4272-9174-3996c1b2b270",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 29 December 1986 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/48447819-0962-40ec-be28-28587bb75954"
#       },
#       "effectiveDateTime": "1986-12-29T13:23:44-06:00",
#       "issued": "1986-12-29T13:23:44.843-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-000000009362",
#         "display": "Dr. Gregorio366 Valdés907"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542239",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542239",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> HEMOGLOBIN A1C </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 13:09:22 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17869;3110412;81;CH;6929384.839996"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33686"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "200"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/200"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542362"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "213",
#           "display": "HEMOGLOBIN A1C"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2007-06-14T16:00:00+00:00",
#         "end": "2011-04-12T13:09:00+00:00"
#       },
#       "issued": "2011-04-12T13:09:22+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542261"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/2542237",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "2542237",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-09-03T16:51:12.718+00:00",
#         "source": "#8sr68niVvnDncWaA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> LAB T </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 12 April 2011 13:06:37 </td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "FILL",
#             "display": "Filler Identifier"
#           } ],
#           "text": "FillerId"
#         },
#         "value": "17867;3110412;79;CH;6929384.839999"
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PLAC",
#             "display": "Placer Identifier"
#           } ],
#           "text": "PlacerId"
#         },
#         "value": "33684"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource FHIR ID"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderResourceFHIRId",
#         "value": "175"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder resource fullUrl"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetResponderFullUrl",
#         "value": "http://ec2-3-139-107-240.us-east-2.compute.amazonaws.com:52773/csp/healthshare/hsods/fhir/r4/DiagnosticReport/175"
#       }, {
#         "use": "usual",
#         "type": {
#           "text": "Target responder eHealth Exchange Hub routing name"
#         },
#         "system": "https://ehealthexchange.org/hub/internal/targetRespondereHxHubRoutingName",
#         "value": "VAInnovationLab"
#       } ],
#       "basedOn": [ {
#         "reference": "ServiceRequest/2542354"
#       } ],
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA100.98"
#           } ],
#           "code": "CH",
#           "display": "CHEMISTRY"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "extension": [ {
#             "url": "http://intersystems.com/fhir/extn/sda3/lib/code-table-translated-s-d-a-coding-standard",
#             "valueString": "VA101.43"
#           } ],
#           "code": "382",
#           "display": "LAB T"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ha-patientSample-5"
#       },
#       "effectivePeriod": {
#         "start": "2007-06-14T16:00:00+00:00",
#         "end": "2011-04-12T13:06:00+00:00"
#       },
#       "issued": "2011-04-12T13:06:37+00:00",
#       "performer": [ {
#         "reference": "Practitioner/2542317"
#       } ],
#       "result": [ {
#         "reference": "Observation/2542355"
#       }, {
#         "reference": "Observation/2542284"
#       }, {
#         "reference": "Observation/2542269"
#       }, {
#         "reference": "Observation/2542279"
#       }, {
#         "reference": "Observation/2542356"
#       }, {
#         "reference": "Observation/2542281"
#       }, {
#         "reference": "Observation/2542265"
#       }, {
#         "reference": "Observation/2542246"
#       }, {
#         "reference": "Observation/2542287"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/d679ff13-01a2-4cca-90ab-2e26eca5a61f",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "d679ff13-01a2-4cca-90ab-2e26eca5a61f",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:01:10.215+00:00",
#         "source": "#ijlCUFxe2RZuMum2",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 05 April 1964 01:26:46</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/a1562c58-6a5a-4986-ad56-67b081e43504"
#       },
#       "encounter": {
#         "reference": "Encounter/43def292-8153-4d0d-a172-a5b90c35e9ef"
#       },
#       "effectiveDateTime": "1964-04-04T19:26:46-06:00",
#       "issued": "1964-04-04T19:26:46.691-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-00000003ec06",
#         "display": "Dr. Branden904 Abshire638"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/DiagnosticReport/eba5b86c-0d52-433d-b1d5-ee2cebb20efb",
#     "resource": {
#       "resourceType": "DiagnosticReport",
#       "id": "eba5b86c-0d52-433d-b1d5-ee2cebb20efb",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:00:31.816+00:00",
#         "source": "#6SbB93pmUicRlB2M",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-diagnosticreport-note" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\"> Evaluation+Plan note </div><table class=\"hapiPropertyTable\"><tbody><tr><td>Status</td><td>FINAL</td></tr><tr><td>Issued</td><td> 23 December 1985 19:23:44</td></tr></tbody></table></div>"
#       },
#       "status": "final",
#       "category": [ {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://loinc.org",
#           "code": "51847-2",
#           "display": "Evaluation+Plan note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/ce1b4ef9-474f-45b8-a174-01b9f8e9d614"
#       },
#       "encounter": {
#         "reference": "Encounter/93fabd55-fdb0-4096-885b-e422bbbcd365"
#       },
#       "effectiveDateTime": "1985-12-23T13:23:44-06:00",
#       "issued": "1985-12-23T13:23:44.843-06:00",
#       "performer": [ {
#         "reference": "Practitioner/0000016f-a1db-e77f-0000-000000009362",
#         "display": "Dr. Gregorio366 Valdés907"
#       } ],
#       "presentedForm": [ {
#         "contentType": "text/plain",
#         "data": "..."
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %%
# Alle Diagnosen von Patienten mit Geburtsjahr 1930
req = url + 'Condition?patient.birthdate=1930'
response = requests.request("GET", req, headers=headers)
print(str(response.text))
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "146a63d2-7ddd-4fc9-bbbc-5bbe1523977e",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:26:58.854+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Condition?patient.birthdate=1930"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=146a63d2-7ddd-4fc9-bbbc-5bbe1523977e&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/6966594",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "6966594",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-08-22T21:18:20.961+00:00",
#         "source": "#wIhXIGKf5Hsjs3df"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "73211009",
#           "display": "Diabetes mellitus (disorder)"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/6966588"
#       },
#       "encounter": {
#         "reference": "Encounter/6966591"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/2679606",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "2679606",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-11-10T18:28:10.905+00:00",
#         "source": "#myfrHPhsY9a1m8AQ"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Neuropathic pain</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "247389009",
#           "display": "neuropathic pain"
#         } ],
#         "text": "neuropathic pain"
#       },
#       "subject": {
#         "reference": "Patient/2679600"
#       },
#       "onsetAge": {
#         "value": 75,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/afbab577-e065-475d-b98b-0120cb8a5fca",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "afbab577-e065-475d-b98b-0120cb8a5fca",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T17:54:28.626+00:00",
#         "source": "#VcTLiX4aBLgZygxm",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "271737000",
#           "display": "Anemia (disorder)"
#         } ],
#         "text": "Anemia (disorder)"
#       },
#       "subject": {
#         "reference": "Patient/28698b68-29df-4c00-8360-50118f14db1c"
#       },
#       "encounter": {
#         "reference": "Encounter/10639cc2-0faa-4b34-925e-184799d8c13a"
#       },
#       "onsetDateTime": "1985-11-29T13:23:44-06:00",
#       "recordedDate": "1985-11-29T13:23:44-06:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1425646",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1425646",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-07-31T13:13:13.774+00:00",
#         "source": "#Zng0I1C8i3JkX2o4"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Angina</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "Moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "194818000",
#           "display": "angina"
#         } ],
#         "text": "angina"
#       },
#       "subject": {
#         "reference": "Patient/1425634"
#       },
#       "onsetAge": {
#         "value": 76,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       },
#       "evidence": [ {
#         "code": [ {
#           "coding": [ {
#             "system": "http://snomed.info/ct",
#             "code": "29857009",
#             "display": "Chest Pain"
#           } ],
#           "text": "Chest Pain"
#         } ]
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/4c02da41-8d6f-448b-b281-af1bf30710b5",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "4c02da41-8d6f-448b-b281-af1bf30710b5",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T23:57:31.970+00:00",
#         "source": "#h26glm94evoxfgnF",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "399211009",
#           "display": "History of myocardial infarction (situation)"
#         } ],
#         "text": "History of myocardial infarction (situation)"
#       },
#       "subject": {
#         "reference": "Patient/cc3bcf56-5df5-40b3-867f-edec8caa91eb"
#       },
#       "encounter": {
#         "reference": "Encounter/8e7df44f-7840-4a42-8577-052fbe4f96d8"
#       },
#       "onsetDateTime": "2010-05-31T14:23:44-05:00",
#       "recordedDate": "2010-05-31T14:23:44-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1963446",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1963446",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-03-22T19:20:12.673+00:00",
#         "source": "#LtQGZp0gYUi6Litz"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "12676007",
#           "display": "Fracture of radius"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/1963442"
#       },
#       "encounter": {
#         "reference": "Encounter/1963444"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1425643",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1425643",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-07-31T13:13:13.774+00:00",
#         "source": "#Zng0I1C8i3JkX2o4"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">GERD</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "Moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "235595009",
#           "display": "GERD"
#         } ],
#         "text": "GERD"
#       },
#       "subject": {
#         "reference": "Patient/1425634"
#       },
#       "onsetAge": {
#         "value": 66,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1964656",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1964656",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-03-24T08:39:14.813+00:00",
#         "source": "#yMpXsb2nM2UJsF5z"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "37449000",
#           "display": "Open fracture of ulna (disorder)"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/1964651"
#       },
#       "encounter": {
#         "reference": "Encounter/1964653"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/c42c2733-40e7-4f5b-a7a8-044fbe90aa60",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "c42c2733-40e7-4f5b-a7a8-044fbe90aa60",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T20:19:25.316+00:00",
#         "source": "#TZQgturmyJvmu5Gb",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "88805009",
#           "display": "Chronic congestive heart failure (disorder)"
#         } ],
#         "text": "Chronic congestive heart failure (disorder)"
#       },
#       "subject": {
#         "reference": "Patient/78ec4a08-fe7d-4f45-86a0-ba37e6fd1643"
#       },
#       "encounter": {
#         "reference": "Encounter/1e5215ff-c455-4b72-84e9-c50c177cf860"
#       },
#       "onsetDateTime": "2000-10-21T17:12:48-05:00",
#       "recordedDate": "2000-10-21T17:12:48-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/da0fb864-1d5e-4f0a-a580-3263e18c58d6",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "da0fb864-1d5e-4f0a-a580-3263e18c58d6",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T19:25:32.120+00:00",
#         "source": "#bRogF3rUQoTzGtnn",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "88805009",
#           "display": "Chronic congestive heart failure (disorder)"
#         } ],
#         "text": "Chronic congestive heart failure (disorder)"
#       },
#       "subject": {
#         "reference": "Patient/95d9bb93-60a0-4ebf-af73-d7c47b24d75c"
#       },
#       "encounter": {
#         "reference": "Encounter/9f05cef2-aabc-495d-b6f1-e49e5f16b70f"
#       },
#       "onsetDateTime": "1996-04-10T06:12:05-05:00",
#       "recordedDate": "1996-04-10T06:12:05-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/2679610",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "2679610",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-11-10T18:28:10.905+00:00",
#         "source": "#myfrHPhsY9a1m8AQ"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Hypercholesterolaemia</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "Moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "13644009",
#           "display": "high cholesterol"
#         } ],
#         "text": "high cholesterol"
#       },
#       "subject": {
#         "reference": "Patient/2679600"
#       },
#       "onsetAge": {
#         "value": 68,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/2955698",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "2955698",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-05-17T02:14:49.559+00:00",
#         "source": "#74qlMjMZxBQLpva0"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Onychomycosis</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "24484000",
#           "display": "severe"
#         } ],
#         "text": "severe"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "414941998",
#           "display": "onychomycosis"
#         } ],
#         "text": "onychomycosis"
#       },
#       "subject": {
#         "reference": "Patient/2955687"
#       },
#       "onsetAge": {
#         "value": 77,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1964655",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1964655",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-03-24T08:39:14.326+00:00",
#         "source": "#5xMoerSbYea3kspO"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "12676007",
#           "display": "Fracture of radius"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/1964651"
#       },
#       "encounter": {
#         "reference": "Encounter/1964653"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1964174",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1964174",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-03-23T20:59:06.741+00:00",
#         "source": "#96Gri2MAqcPQedFM"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "73211009",
#           "display": "Diabetes mellitus (disorder)"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/1964168"
#       },
#       "encounter": {
#         "reference": "Encounter/1964171"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1425644",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1425644",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-07-31T13:13:13.774+00:00",
#         "source": "#Zng0I1C8i3JkX2o4"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Hypercholesterolaemia</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "Moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "13644009",
#           "display": "high cholesterol"
#         } ],
#         "text": "high cholesterol"
#       },
#       "subject": {
#         "reference": "Patient/1425634"
#       },
#       "onsetAge": {
#         "value": 68,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1964657",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1964657",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2021-03-24T08:39:15.009+00:00",
#         "source": "#Ab1V7b5mur35ljOg"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "73211009",
#           "display": "Diabetes mellitus (disorder)"
#         } ],
#         "text": "Facture of radius"
#       },
#       "subject": {
#         "reference": "Patient/1964651"
#       },
#       "encounter": {
#         "reference": "Encounter/1964654"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/2955697",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "2955697",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-05-17T02:14:49.559+00:00",
#         "source": "#74qlMjMZxBQLpva0"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Hypercholesterolaemia</div>"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "14657009",
#           "display": "Diagnosis"
#         } ],
#         "text": "Diagnosis"
#       } ],
#       "severity": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "6736007",
#           "display": "moderate"
#         } ],
#         "text": "Moderate"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/ct",
#           "code": "13644009",
#           "display": "high cholesterol"
#         } ],
#         "text": "high cholesterol"
#       },
#       "subject": {
#         "reference": "Patient/2955687"
#       },
#       "onsetAge": {
#         "value": 68,
#         "system": "http://unitsofmeasure.org",
#         "code": "a"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/6b68f32f-ac3e-4551-9f4e-8745cef3b9ba",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "6b68f32f-ac3e-4551-9f4e-8745cef3b9ba",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T18:02:20.243+00:00",
#         "source": "#VgJk88pfOxoPfL8G",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "271737000",
#           "display": "Anemia (disorder)"
#         } ],
#         "text": "Anemia (disorder)"
#       },
#       "subject": {
#         "reference": "Patient/adb9a45d-78dd-43a5-aa24-4f87b1cfa8c0"
#       },
#       "encounter": {
#         "reference": "Encounter/ba1f8f33-f47a-4e69-9402-73fd15d33cab"
#       },
#       "onsetDateTime": "1991-11-28T13:23:44-06:00",
#       "recordedDate": "1991-11-28T13:23:44-06:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/8beeb25c-633a-4cbe-9605-4103c1e808a9",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "8beeb25c-633a-4cbe-9605-4103c1e808a9",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T19:25:32.120+00:00",
#         "source": "#bRogF3rUQoTzGtnn",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "230690007",
#           "display": "Stroke"
#         } ],
#         "text": "Stroke"
#       },
#       "subject": {
#         "reference": "Patient/95d9bb93-60a0-4ebf-af73-d7c47b24d75c"
#       },
#       "encounter": {
#         "reference": "Encounter/58aecf01-b4ef-430c-87f3-cdb1c53568cb"
#       },
#       "onsetDateTime": "1983-07-19T06:12:05-05:00",
#       "recordedDate": "1983-07-19T06:12:05-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/6b7355fa-c330-4dae-9bdc-3ea3d37c2e10",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "6b7355fa-c330-4dae-9bdc-3ea3d37c2e10",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-24T22:18:22.724+00:00",
#         "source": "#pFYASNXcWbsK5zDL",
#         "profile": [ "http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition" ],
#         "tag": [ {
#           "system": "https://smarthealthit.org/tags",
#           "code": "Covid19 synthetic population from Synthea"
#         } ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "410429000",
#           "display": "Cardiac Arrest"
#         } ],
#         "text": "Cardiac Arrest"
#       },
#       "subject": {
#         "reference": "Patient/be1f7bc3-e81c-4ba7-839c-fd96a8d25471"
#       },
#       "encounter": {
#         "reference": "Encounter/72248c1d-106a-446a-b9f6-37c494649bf6"
#       },
#       "onsetDateTime": "2019-02-18T23:40:03-06:00",
#       "recordedDate": "2019-02-18T23:40:03-06:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %% [markdown]
# # Reverse chained search

# %%
# Search for all Patients with Diabetes Mellitus

req = url + 'Patient' + '?' + '_has:Condition:patient:code=http://snomed.info/sct|44054006' + '&_summary=count'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "11942c9a-cbed-4d69-8bcd-62315fc32f4d",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:27:00.133+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "total": 82
# }

# %%
# Anzahl der Patienten mit einer Observation "Heart Rate"
# https://loinc.org/8867-4/

code = "8867-4"

req = url + "Patient?_has:Observation:patient:code=" + code + "&_summary=count"
response = requests.request("GET", req, headers=headers)
print("Anzahl der Patienten: " + str(response.json().get('total')))
print(response.text)
# Out:
# Anzahl der Patienten: 5845
# {
#   "resourceType": "Bundle",
#   "id": "c2e834e8-d50c-4fdb-80de-3b1d179008c9",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:27:00.488+00:00",
#     "tag": [ {
#       "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationValue",
#       "code": "SUBSETTED",
#       "display": "Resource encoded in summary mode"
#     } ]
#   },
#   "type": "searchset",
#   "total": 5845
# }

# %%
# Alle Patienten zurück geben mit einer gewissen Observation (idF. Heart Rate)
# Wenn es viele Treffer gibt, dann wird "Pageing" aktiviert.

req = url + "Patient?_has:Observation:patient:code=8867-4"

# die ersten 5 Ergebnisse zurückgebe
req = url + "Patient?_has:Observation:patient:code=8867-4&_count=5&_sort=-_lastUpdated"


response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "1156f11e-6a3f-435b-9052-dbfa95254207",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:27:08.219+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?_count=5&_has%3AObservation%3Apatient%3Acode=8867-4&_sort=-_lastUpdated"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=1156f11e-6a3f-435b-9052-dbfa95254207&_getpagesoffset=5&_count=5&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7198903",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7198903",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-13T14:21:01.360+00:00",
#         "source": "#79Y22jJNcs9cOtNc"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTFJEDR </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtFjeDR",
#         "family": "WienerNeustadtFjeDR",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/b18052e2-9138-4d73-a373-78bf78ba5f98",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "b18052e2-9138-4d73-a373-78bf78ba5f98",
#       "meta": {
#         "versionId": "7",
#         "lastUpdated": "2022-12-13T13:17:20.621+00:00",
#         "source": "#XBTRwvCvjxSksYCC"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Atom <b>ATOMS </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Address</td><td><span>Nairobi </span><span>Kenya </span></td></tr><tr><td>Date of birth</td><td><span>13 July 2021</span></td></tr></tbody></table></div>"
#       },
#       "active": false,
#       "name": [ {
#         "family": "Atoms",
#         "given": [ "Atom" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "1111111111"
#       } ],
#       "gender": "male",
#       "birthDate": "2021-07-13",
#       "address": [ {
#         "city": "NAIROBI",
#         "country": "Kenya"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7197634",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7197634",
#       "meta": {
#         "versionId": "6",
#         "lastUpdated": "2022-12-13T10:22:29.468+00:00",
#         "source": "#TQmmEai6yV349iEo"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Karthikeyan <b>GANESAN </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>170195</td></tr><tr><td>Address</td><td><span>28 Mount road,anna salai </span><br/><span>Chennai </span><span>TamilNadu </span><span>India </span></td></tr><tr><td>Date of birth</td><td><span>17 January 1995</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "code": "MR"
#           } ]
#         },
#         "system": "local",
#         "value": "170195"
#       }, {
#         "use": "secondary",
#         "type": {
#           "coding": [ {
#             "code": "EPI"
#           } ]
#         },
#         "system": "local",
#         "value": "1234"
#       } ],
#       "active": true,
#       "name": [ {
#         "use": "official",
#         "family": "Ganesan",
#         "given": [ "Karthikeyan" ]
#       } ],
#       "telecom": [ {
#         "value": "9980671234",
#         "use": "mobile"
#       } ],
#       "gender": "male",
#       "birthDate": "1995-01-17",
#       "address": [ {
#         "type": "postal",
#         "line": [ "28 Mount road,anna salai" ],
#         "city": "Chennai",
#         "state": "TamilNadu",
#         "country": "India"
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Practitioner/7198554"
#       } ],
#       "managingOrganization": {
#         "reference": "Organization/7197582"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7193626",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7193626",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-12T16:18:50.222+00:00",
#         "source": "#g5D12KnAbWtXxBcW"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">DMFLDSfmels <b>HALLO </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>20 February 2200</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "family": "hallo",
#         "given": [ "DMFLDSfmels" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2200-02-20"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7192035",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7192035",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-11T18:02:13.730+00:00",
#         "source": "#PK4zU27AjLZoygA0"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Sahil <b>KHANNA </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Identifier</td><td>MRN4001615511</td></tr><tr><td>Address</td><td><span>3013 PHILIP AVENUE </span><br/><span>Bangalore </span><span>Karnataka </span><span>India </span></td></tr><tr><td>Date of birth</td><td><span>01 December 1963</span></td></tr></tbody></table></div>"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical record number"
#           } ]
#         },
#         "system": "https://test.org/identifiers/PatientIdentifier",
#         "value": "MRN4001615511"
#       } ],
#       "name": [ {
#         "use": "usual",
#         "family": "Khanna",
#         "given": [ "Sahil" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "(718)931-2514",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1963-12-01",
#       "address": [ {
#         "line": [ "3013 PHILIP AVENUE" ],
#         "city": "Bangalore",
#         "district": "Bangalore Urban district",
#         "state": "Karnataka",
#         "postalCode": "560034",
#         "country": "India"
#       } ]
#     },
#     "search": {
#       "mode": "match"
#     }
#   } ]
# }

# %% [markdown]
# # Include

# %%
# _include lets you search for resource instances and include in the results other resources referenced by the target resource instances. 

req = url + 'Condition?code=http://snomed.info/sct|44054006' + '&' + '_include=Condition:patient'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "0aa311fe-d31a-4f52-a08b-c4d99d9a1369",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:27:10.141+00:00"
#   },
#   "type": "searchset",
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Condition?_include=Condition%3Apatient&code=http%3A%2F%2Fsnomed.info%2Fsct%7C44054006"
#   }, {
#     "relation": "next",
#     "url": "https://hapi.fhir.org/baseR4?_getpages=0aa311fe-d31a-4f52-a08b-c4d99d9a1369&_getpagesoffset=20&_count=20&_pretty=true&_include=Condition%3Apatient&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/601798",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "601798",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:03:45.714+00:00",
#         "source": "#Io7DEVTOm0wT6Mkc"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/601740"
#       },
#       "encounter": {
#         "reference": "Encounter/601797"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/603663",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "603663",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:04:53.396+00:00",
#         "source": "#2Mw6coXZ3eCxig9F"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/603633"
#       },
#       "encounter": {
#         "reference": "Encounter/603662"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/604079",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "604079",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:40:23.794+00:00",
#         "source": "#qKHwJq0NzzHksTmH"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/603996"
#       },
#       "encounter": {
#         "reference": "Encounter/604078"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/604576",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "604576",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:40:24.556+00:00",
#         "source": "#36Rg6RxppVbTXkva"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/604446"
#       },
#       "encounter": {
#         "reference": "Encounter/604575"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/607199",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "607199",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:41:33.607+00:00",
#         "source": "#hmAkcQOGo9j4llII"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/606899"
#       },
#       "encounter": {
#         "reference": "Encounter/607197"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/607954",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "607954",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:41:33.749+00:00",
#         "source": "#7pYuzSrl57wuc17f"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/607924"
#       },
#       "encounter": {
#         "reference": "Encounter/607953"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/608962",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "608962",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:46:40.231+00:00",
#         "source": "#4CxAoexoVVVzZgyn"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/608904"
#       },
#       "encounter": {
#         "reference": "Encounter/608961"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/609412",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "609412",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:46:40.699+00:00",
#         "source": "#LZMM1Vmp8jTY85Zn"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/609303"
#       },
#       "encounter": {
#         "reference": "Encounter/609410"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/611595",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "611595",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:49:36.302+00:00",
#         "source": "#rfTFel0LZO2OmAWp"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/611537"
#       },
#       "encounter": {
#         "reference": "Encounter/611594"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/612201",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "612201",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:49:36.827+00:00",
#         "source": "#btVRlzdAtokxksQF"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/612039"
#       },
#       "encounter": {
#         "reference": "Encounter/612199"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/613824",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "613824",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:50:38.337+00:00",
#         "source": "#GNdNDX5tItXODUdv"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/613766"
#       },
#       "encounter": {
#         "reference": "Encounter/613823"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/614401",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "614401",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:50:38.818+00:00",
#         "source": "#LAfuKQmxUVKya49O"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/614253"
#       },
#       "encounter": {
#         "reference": "Encounter/614373"
#       },
#       "onsetDateTime": "2011-07-17T12:26:16-04:00",
#       "recordedDate": "2011-07-17T12:26:16-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/616756",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "616756",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:51:44.961+00:00",
#         "source": "#OZNdlVvG9Elfsbd8"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/616626"
#       },
#       "encounter": {
#         "reference": "Encounter/616753"
#       },
#       "onsetDateTime": "2016-01-30T09:19:39-05:00",
#       "recordedDate": "2016-01-30T09:19:39-05:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/622919",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "622919",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-18T09:08:21.927+00:00",
#         "source": "#8t1bINv1FvZfbmgd",
#         "profile": [ "https://www.fhir.philips.com/4.0/StructureDefinition/common/resource/general/condition-v1/ILSCondition" ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/622898"
#       },
#       "encounter": {
#         "reference": "Encounter/622918"
#       },
#       "onsetDateTime": "2010-04-08T02:35:56+02:00",
#       "recordedDate": "2010-04-08T02:35:56+02:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/624195",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "624195",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-18T10:20:57.687+00:00",
#         "source": "#QevMc30MwqsbBcpx",
#         "profile": [ "https://www.fhir.philips.com/4.0/StructureDefinition/common/resource/general/condition-v1/ILSCondition" ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/624175"
#       },
#       "encounter": {
#         "reference": "Encounter/624194"
#       },
#       "onsetDateTime": "2011-07-25T18:22:17+02:00",
#       "recordedDate": "2011-07-25T18:22:17+02:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/625760",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "625760",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-09-21T07:57:11.923+00:00",
#         "source": "#ibAf8mokWvwUAcfi",
#         "profile": [ "https://www.fhir.philips.com/4.0/StructureDefinition/common/resource/general/condition-v1/ILSCondition" ]
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10",
#           "code": "E11",
#           "display": "Type 2 Diabetes Mellitus"
#         }, {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes mellitus type 2"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/625740"
#       },
#       "encounter": {
#         "reference": "Encounter/625759"
#       },
#       "onsetDateTime": "2011-07-25T18:22:17+02:00",
#       "recordedDate": "2011-07-25T18:22:17+02:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/LDME-CON1",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "LDME-CON1",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-03-28T01:21:05.265+00:00",
#         "source": "#Jlk4D0fbcffSpqTY"
#       },
#       "category": [ {
#         "coding": [ {
#           "system": "http://argonaut.hl7.org/extension-codes",
#           "code": "problem",
#           "display": "Problem"
#         } ]
#       } ],
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes mellitus type 2"
#         } ],
#         "text": "Diabetes mellitus type 2"
#       }
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1172124",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1172124",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-05-24T11:14:07.235+00:00",
#         "source": "#Zkxq6eL5AJIW3a3z"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Type 2 diabetes mellitus"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/1172122"
#       },
#       "onsetDateTime": "1989",
#       "recordedDate": "2020-05-24T11:14:04.609Z"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1187503",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1187503",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-09-21T07:58:11.769+00:00",
#         "source": "#NYIgd3GbK3ItDnOV"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10",
#           "code": "E11",
#           "display": "Type 2 Diabetes Mellitus"
#         }, {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes mellitus type 2"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/1187338"
#       },
#       "encounter": {
#         "reference": "Encounter/1187502"
#       },
#       "onsetDateTime": "2016-10-07T00:05:41-04:00",
#       "recordedDate": "2016-10-07T00:05:41-04:00"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/1378327",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "1378327",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-09-21T07:59:06.144+00:00",
#         "source": "#dHJcPvKH00Ce3UzN"
#       },
#       "clinicalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#           "code": "active"
#         } ]
#       },
#       "verificationStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#           "code": "confirmed"
#         } ]
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10",
#           "code": "E11",
#           "display": "Type 2 Diabetes Mellitus"
#         }, {
#           "system": "http://snomed.info/sct",
#           "code": "44054006",
#           "display": "Diabetes mellitus type 2"
#         } ],
#         "text": "Diabetes"
#       },
#       "subject": {
#         "reference": "Patient/1378388"
#       },
#       "encounter": {
#         "reference": "Encounter/1378316"
#       },
#       "onsetDateTime": "2019-10-07T10:09:41",
#       "recordedDate": "2019-10-07T10:09:41"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/608904",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "608904",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:46:40.231+00:00",
#         "source": "#4CxAoexoVVVzZgyn"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: 1507219752436740101  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2131-1",
#             "display": "Other"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Other"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Lilliana632 Legros616"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Taunton",
#           "state": "Massachusetts",
#           "country": "US"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 0.2610319411407842
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 27.738968058859214
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-53-3442"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99919140"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X86002591X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Gulgowski816",
#         "given": [ "Vaughn909" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-686-9116",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1990-11-24",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.42746009048756
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.02154293326397
#           } ]
#         } ],
#         "line": [ "723 Kunze Road Suite 9" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "en-US",
#             "display": "English"
#           } ],
#           "text": "English"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/1378388",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "1378388",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-07-09T02:46:20.008+00:00",
#         "source": "#NaZgppuchNKpzrgZ"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">นายกิตติชัย อัศวศิริโสภากุล</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2028-9",
#             "display": "Asian"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Asian"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       } ],
#       "identifier": [ {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://demo.si.mahidol.ac.th/hn",
#         "value": "510001"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NNTHA",
#             "display": "Thai National ID"
#           } ],
#           "text": "Thai National ID"
#         },
#         "system": "https://demo.bora.dopa.go.th/cid",
#         "value": "1234567890123"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X71676871X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "อัศวศิริโสภากุล",
#         "given": [ "กิตติชัย" ],
#         "prefix": [ "นาย" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-643-4236",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1956-04-13",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 13.793648
#           }, {
#             "url": "longitude",
#             "valueDecimal": 100.32231
#           } ]
#         } ],
#         "text": "25/25 หมู่ 5 ถ.พุทธมณฑลสาย 4 ต.ศาลายา อ.พุทธมณฑล จ.นครปฐม",
#         "line": [ "25/25 หมู่ 5 ถ.พุทธมณฑลสาย 4" ],
#         "city": "ศาลายา",
#         "district": "พุทธมณฑล",
#         "state": "นครปฐม",
#         "postalCode": "73170",
#         "country": "TH"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "Married"
#         } ],
#         "text": "สมรส"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "th-TH",
#             "display": "Thai"
#           } ],
#           "text": "ภาษาไทย"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/614253",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "614253",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:50:38.818+00:00",
#         "source": "#LAfuKQmxUVKya49O"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: -1947326395900975778  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2028-9",
#             "display": "Asian"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Asian"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Jamee262 Wyman904"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Shanghai",
#           "state": "Shanghai Municipality",
#           "country": "CN"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 1.6187463503674218
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 42.381253649632576
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-57-3953"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99951667"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X59212283X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Leannon79",
#         "given": [ "Erick204" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-431-6914",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1974-04-28",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.29994140676488
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.06806500600902
#           } ]
#         } ],
#         "line": [ "267 Schroeder Viaduct Unit 83" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "zh",
#             "display": "Chinese"
#           } ],
#           "text": "Chinese"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/625740",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "625740",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-25T09:54:45.477+00:00",
#         "source": "#QETslP8cqhK4fMAO",
#         "profile": [ "https://www.fhir.philips.com/4.0/StructureDefinition/common/resource/general/patient-v1/ILSPatient" ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: f0c3351\n .   Person seed: 1756536222269054029  Population seed: 1582019000517</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "detailed",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2131-1",
#             "display": "Other Races"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Other"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2135-2",
#             "display": "Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Margarita164 Quiroz936"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Brasilia",
#           "state": "Federal District",
#           "country": "BR"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 52.48470729428387
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 3.515292705716128
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "1b28e4b5-9581-42da-ad60-a6789833ef7b"
#       }, {
#         "system": "Philips code test system",
#         "value": "1b28e4b5-9581-42da-ad60-a6789833ef7b"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "1b28e4b5-9581-42da-ad60-a6789833ef7b"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-96-8225"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99937070"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X47259164X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Villegas15",
#         "given": [ "Ernesto186" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-166-3296",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1963-07-01",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.31371086281806
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.61081859597851
#           } ]
#         } ],
#         "line": [ "886 Kreiger Gateway Apt 36" ],
#         "city": "Westborough",
#         "state": "Massachusetts",
#         "postalCode": "01581",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "es",
#             "display": "Spanish"
#           } ],
#           "text": "Spanish"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/601740",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "601740",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:03:45.714+00:00",
#         "source": "#Io7DEVTOm0wT6Mkc"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: 1507219752436740101  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2131-1",
#             "display": "Other"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Other"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Lilliana632 Legros616"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Taunton",
#           "state": "Massachusetts",
#           "country": "US"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 0.2610319411407842
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 27.738968058859214
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-53-3442"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99919140"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X86002591X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Gulgowski816",
#         "given": [ "Vaughn909" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-686-9116",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1990-11-24",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.42746009048756
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.02154293326397
#           } ]
#         } ],
#         "line": [ "723 Kunze Road Suite 9" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "en-US",
#             "display": "English"
#           } ],
#           "text": "English"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/624175",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "624175",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-18T10:20:57.687+00:00",
# ...
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "en-US",
#             "display": "English"
#           } ],
#           "text": "English"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/616626",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "616626",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:51:44.961+00:00",
#         "source": "#OZNdlVvG9Elfsbd8"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: 1507219752436740101  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2131-1",
#             "display": "Other"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Other"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Lilliana632 Legros616"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Taunton",
#           "state": "Massachusetts",
#           "country": "US"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 0.2610319411407842
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 27.738968058859214
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "98bc4c6d-5bdd-46a7-9e94-301d0fee848e"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-53-3442"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99919140"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X86002591X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Gulgowski816",
#         "given": [ "Vaughn909" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-686-9116",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1990-11-24",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.42746009048756
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.02154293326397
#           } ]
#         } ],
#         "line": [ "723 Kunze Road Suite 9" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "en-US",
#             "display": "English"
#           } ],
#           "text": "English"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/607924",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "607924",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2020-02-07T11:41:33.749+00:00",
#         "source": "#7pYuzSrl57wuc17f"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: -1947326395900975778  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2028-9",
#             "display": "Asian"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Asian"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Jamee262 Wyman904"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Shanghai",
#           "state": "Shanghai Municipality",
#           "country": "CN"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 1.6187463503674218
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 42.381253649632576
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-57-3953"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99951667"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X59212283X"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Leannon79",
#         "given": [ "Erick204" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-431-6914",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1974-04-28",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.29994140676488
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.06806500600902
#           } ]
#         } ],
#         "line": [ "267 Schroeder Viaduct Unit 83" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "zh",
#             "display": "Chinese"
#           } ],
#           "text": "Chinese"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/609303",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "609303",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-03-25T16:38:42.452+00:00",
#         "source": "#3mUjm9CwL2fRrx5L"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">Generated by <a href=\"https://github.com/synthetichealth/synthea\">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: -1947326395900975778  Population seed: 0</div>"
#       },
#       "extension": [ {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2028-9",
#             "display": "Asian"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Asian"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity",
#         "extension": [ {
#           "url": "ombCategory",
#           "valueCoding": {
#             "system": "urn:oid:2.16.840.1.113883.6.238",
#             "code": "2186-5",
#             "display": "Not Hispanic or Latino"
#           }
#         }, {
#           "url": "text",
#           "valueString": "Not Hispanic or Latino"
#         } ]
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName",
#         "valueString": "Jamee262 Wyman904"
#       }, {
#         "url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex",
#         "valueCode": "M"
#       }, {
#         "url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace",
#         "valueAddress": {
#           "city": "Shanghai",
#           "state": "Shanghai Municipality",
#           "country": "CN"
#         }
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years",
#         "valueDecimal": 1.6187463503674218
#       }, {
#         "url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years",
#         "valueDecimal": 42.381253649632576
#       } ],
#       "identifier": [ {
#         "system": "https://github.com/synthetichealth/synthea",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR",
#             "display": "Medical Record Number"
#           } ],
#           "text": "Medical Record Number"
#         },
#         "system": "http://hospital.smarthealthit.org",
#         "value": "da24e588-37fe-47aa-9780-4d154d84df5c"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "SS",
#             "display": "Social Security Number"
#           } ],
#           "text": "Social Security Number"
#         },
#         "system": "http://hl7.org/fhir/sid/us-ssn",
#         "value": "999-57-3953"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "DL",
#             "display": "Driver's License"
#           } ],
#           "text": "Driver's License"
#         },
#         "system": "urn:oid:2.16.840.1.113883.4.3.25",
#         "value": "S99951667"
#       }, {
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "PPN",
#             "display": "Passport Number"
#           } ],
#           "text": "Passport Number"
#         },
#         "system": "http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber",
#         "value": "X59212283Xyz"
#       } ],
#       "name": [ {
#         "use": "official",
#         "family": "Leannon79",
#         "given": [ "Erick204" ],
#         "prefix": [ "Mr." ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "555-431-6914",
#         "use": "home"
#       } ],
#       "gender": "male",
#       "birthDate": "1974-04-28",
#       "address": [ {
#         "extension": [ {
#           "url": "http://hl7.org/fhir/StructureDefinition/geolocation",
#           "extension": [ {
#             "url": "latitude",
#             "valueDecimal": 42.29994140676488
#           }, {
#             "url": "longitude",
#             "valueDecimal": -71.06806500600902
#           } ]
#         } ],
#         "line": [ "267 Schroeder Viaduct Unit 83" ],
#         "city": "Boston",
#         "state": "Massachusetts",
#         "postalCode": "02108",
#         "country": "US"
#       } ],
#       "maritalStatus": {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus",
#           "code": "M",
#           "display": "M"
#         } ],
#         "text": "M"
#       },
#       "multipleBirthBoolean": false,
#       "communication": [ {
#         "language": {
#           "coding": [ {
#             "system": "urn:ietf:bcp:47",
#             "code": "zh",
#             "display": "Chinese"
#           } ],
#           "text": "Chinese"
#         }
#       } ]
#     },
#     "search": {
#       "mode": "include"
#     }
#   } ]
# }

# %% [markdown]
# # Reverse Include

# %%
#_revinclude allows you to search for resource instances and include in the results other resources that reference the target resource instances. 
req = url + 'Patient?name=WienerNeustadt&gender=female&birthdate=2022-12-05' + '&' + '_revinclude=Condition:patient'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "c3a4a908-e344-46ba-beb0-ac731b6c898f",
#   "meta": {
#     "lastUpdated": "2022-12-13T14:27:10.541+00:00"
#   },
#   "type": "searchset",
#   "total": 6,
#   "link": [ {
#     "relation": "self",
#     "url": "https://hapi.fhir.org/baseR4/Patient?_revinclude=Condition%3Apatient&birthdate=2022-12-05&gender=female&name=WienerNeustadt"
#   } ],
#   "entry": [ {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185197",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185197",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:33:01.605+00:00",
#         "source": "#2eopjhS2NavITyoA"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNJRLM </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNJrLm",
#         "family": "WienerNeustadtNJrLm",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185273",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185273",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:21.234+00:00",
#         "source": "#9Grm3F5PtjTzLfMh"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTZCATK </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtzcaTk",
#         "family": "WienerNeustadtzcaTk",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185274",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185274",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:24.704+00:00",
#         "source": "#2lmdbIo15meQh68T"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTOGHDE </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtOgHDe",
#         "family": "WienerNeustadtOgHDe",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185275",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185275",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:40:34.390+00:00",
#         "source": "#XtNqiLTeSWGWWGGj"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTNWUZL </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtNWuZl",
#         "family": "WienerNeustadtNWuZl",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7185301",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7185301",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T19:36:45.546+00:00",
#         "source": "#OReKzjEcNwhrt9n6"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTQGEHT </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtQGeHt",
#         "family": "WienerNeustadtQGeHt",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Patient/7198903",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "7198903",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-13T14:21:01.360+00:00",
#         "source": "#79Y22jJNcs9cOtNc"
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><div class=\"hapiHeaderText\">Fachhochschule <b>WIENERNEUSTADTFJEDR </b></div><table class=\"hapiPropertyTable\"><tbody><tr><td>Date of birth</td><td><span>05 December 2022</span></td></tr></tbody></table></div>"
#       },
#       "name": [ {
#         "use": "official",
#         "text": "Fachhochschule WienerNeustadtFjeDR",
#         "family": "WienerNeustadtFjeDR",
#         "given": [ "Fachhochschule" ]
#       } ],
#       "gender": "female",
#       "birthDate": "2022-12-05"
#     },
#     "search": {
#       "mode": "match"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185304",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185304",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T19:36:48.483+00:00",
#         "source": "#O6wFW5k4ClOo2O14"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185301"
#       },
#       "encounter": {
#         "reference": "Encounter/7185302"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7198906",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7198906",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-13T14:21:03.079+00:00",
#         "source": "#li36mJ2ZGbqjDtVQ"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7198903"
#       },
#       "encounter": {
#         "reference": "Encounter/7198904"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185205",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185205",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:36:47.234+00:00",
#         "source": "#fkx8L0bIRfV87Kw3"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185197"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185284",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185284",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:47:56.511+00:00",
#         "source": "#ZK66KwMXXB91giua"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185275"
#       },
#       "encounter": {
#         "reference": "Encounter/7185278"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185206",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185206",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T15:39:04.904+00:00",
#         "source": "#1HGvYIjOmEpnmBfq"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185197"
#       },
#       "encounter": {
#         "reference": "Encounter/7185198"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   }, {
#     "fullUrl": "https://hapi.fhir.org/baseR4/Condition/7185281",
#     "resource": {
#       "resourceType": "Condition",
#       "id": "7185281",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2022-12-05T18:46:48.859+00:00",
#         "source": "#eFUmH8YtLfaKy6K6"
#       },
#       "code": {
#         "coding": [ {
#           "system": "http://hl7.org/fhir/sid/icd-10-us",
#           "code": "E10.65",
#           "display": "Type 1 Diabetes Mellitus with Hyperglycemia"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/7185273"
#       },
#       "encounter": {
#         "reference": "Encounter/7185279"
#       }
#     },
#     "search": {
#       "mode": "include"
#     }
#   } ]
# }

# %% [markdown]
# # AddOn

# %%
# Daten exportieren, wird nicht von jedem FHIR-Server unterstützt
req = url + '$export' + '?' + '_type=Patient,Condition'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# {
#   "resourceType": "OperationOutcome",
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><h1>Operation Outcome</h1><table border=\"0\"><tr><td style=\"font-weight: bold;\">ERROR</td><td>[]</td><td><pre>HAPI-0513: Must request async processing for $export</pre></td>\n\t\t\t</tr>\n\t\t</table>\n\t</div>"
#   },
#   "issue": [ {
#     "severity": "error",
#     "code": "processing",
#     "diagnostics": "HAPI-0513: Must request async processing for $export"
#   } ]
# }

# %%
# Konfiguration des FHIR-Servers abrufen - wichtig um zu wissen, welche Ressourcen/ Funktionen untersützt werden.
# !! es muss nicht jeder FHIR-Server die gesamte Spezifikation unterstützen !!
req = url + 'metadata'
response = requests.request("GET", req, headers=headers)
print(response.text)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

# Ergebnis (JSON) in Pandas Dataframe konvertieren
req = url + 'Patient' + '?' + '_has:Condition:patient:code=http://snomed.info/sct|44054006&_elements=id,gender,birthDate'
response = requests.request("GET", req, headers=headers)
#print(response.text)

data = json.loads(response.text)

df = pd.json_normalize(data, 'entry')
df.describe()
# Out:
#                                             fullUrl resource.resourceType  \
# count                                            20                    20
# unique                                           20                     1
# top     https://hapi.fhir.org/baseR4/Patient/601740               Patient
# freq                                              1                    20
#
#        resource.id resource.meta.versionId      resource.meta.lastUpdated  \
# count           20                      20                             20
# unique          20                       3                             20
# top         601740                       1  2020-02-07T11:03:45.714+00:00
# freq             1                      17                              1
#
#        resource.meta.source  \
# count                    20
# unique                   20
# top       #Io7DEVTOm0wT6Mkc
# freq                      1
#
#                                         resource.meta.tag resource.gender  \
# count                                                  20              20
# unique                                                  2               2
# top     [{'system': 'http://terminology.hl7.org/CodeSy...            male
# freq                                                   19              18
#
#        resource.birthDate search.mode  \
# count                  20          20
# unique                  8           1
# top            1990-11-24       match
# freq                    7          20
#
#                                     resource.meta.profile
# count                                                   3
# unique                                                  1
# top     [https://www.fhir.philips.com/4.0/StructureDef...
# freq                                                    3

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (8.0.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (305.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)

# %%
pip install fhirclient
# Out:
# Collecting fhirclient
#   Downloading fhirclient-4.1.0-py2.py3-none-any.whl (683 kB)
#                                               0.0/683.2 kB ? eta -:--:--
#      ---------------------                 389.1/683.2 kB 12.2 MB/s eta 0:00:01
#      ------------------------------------  675.8/683.2 kB 14.2 MB/s eta 0:00:01
#      -------------------------------------- 683.2/683.2 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from fhirclient) (2.29.0)
# Collecting isodate (from fhirclient)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#                                               0.0/41.7 kB ? eta -:--:--
#      -------------------------------------- 41.7/41.7 kB 669.8 kB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from isodate->fhirclient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->fhirclient) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->fhirclient) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->fhirclient) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->fhirclient) (2023.5.7)
# Installing collected packages: isodate, fhirclient
# Successfully installed fhirclient-4.1.0 isodate-0.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display
#from fhir.resources import Patient, Observation
from fhir.resources.patient import Patient
from fhir.resources.observation import Observation
from fhirclient import client

# Funktion zur Abfrage und Anzeige der Observationen
def fetch_and_display_observations(patient_id, url):
    server = client.FHIRClient(url)
    patient = Patient.read(patient_id, server)
    
    if patient:
        observations = Observation.where(struct={"subject": patient_id}, server=server)
        observation_list.value = "Observations for Patient: {}\n".format(patient.name[0].text)
        for obs in observations:
            observation_list.value += "{}: {}\n".format(obs.code.text, obs.valueQuantity.value)
    else:
        observation_list.value = "Patient not found."

# Erstellen der Widgets
patient_id_input = widgets.Text(placeholder="Enter Patient ID", description="Patient ID:")
fetch_button = widgets.Button(description="Fetch Observations")
observation_list = widgets.HTML(value="")

# Funktion beim Klick auf den "Fetch Observations"-Button ausführen
def on_fetch_button_clicked(b):
    patient_id = patient_id_input.value
    fetch_and_display_observations(patient_id, url)

fetch_button.on_click(on_fetch_button_clicked)

# Anzeigen der Widgets
display(patient_id_input, fetch_button, observation_list)
# Out:
# Text(value='', description='Patient ID:', placeholder='Enter Patient ID')
# Button(description='Fetch Observations', style=ButtonStyle())
# HTML(value='')
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 29, in on_fetch_button_clicked(b)
#      27 def on_fetch_button_clicked(b):
#      28     patient_id = patient_id_input.value
# ---> 29     fetch_and_display_observations(patient_id, url)
#
# Cell In[21], line 10, in fetch_and_display_observations(patient_id, url)
#       9 def fetch_and_display_observations(patient_id, url):
# ---> 10     server = client.FHIRClient(url)
#      11     patient = Patient.read(patient_id, server)
#      13     if patient:
#
# File ~\anaconda3\Lib\site-packages\fhirclient\client.py:68, in FHIRClient.__init__(self, settings, state, save_func)
#      66 elif settings is not None:
#      67     if not 'app_id' in settings:
# ---> 68         raise Exception("Must provide 'app_id' in settings dictionary")
#      69     if not 'api_base' in settings:
#      70         raise Exception("Must provide 'api_base' in settings dictionary")
#
# Exception: Must provide 'app_id' in settings dictionary
