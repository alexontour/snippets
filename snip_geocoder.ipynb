# %%
# !pip install geocoder
import geocoder
#import geopy
# !pip install geopy
from geopy.geocoders import Nominatim
from geopy import distance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 98 kB 3.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
address = geocoder.osm("Müllner Hauptstraße 48 5020 Salzburg")
address_latlng = [address.lat, address.lng]
address_latlng
# Out:
# [47.8077775, 13.0310722]

# %%
# https://peterhaas-me.medium.com/how-to-geocode-with-python-and-pandas-4cd1d717d3f7
geolocator = Nominatim(timeout=10, user_agent = "myGeolocator")
location = geolocator.geocode('Müllner Hauptstraße 48 5020 Salzburg')
print(location)
print((location.latitude, location.longitude))
# Out:
# Müllner Hauptstraße, 48, Müllner Hauptstraße, Mülln, Salzburg, 5020, Österreich
# (47.8077775, 13.0310722)

# %%
# Distance
# https://peterhaas-me.medium.com/how-to-geocode-with-python-and-pandas-4cd1d717d3f7

location_1 = geolocator.geocode('Salzburg')
location_1_gps = (location_1.latitude, location_1.longitude)
location_2 = geolocator.geocode('Redlham')
location_2_gps = (location_2.latitude, location_2.longitude)


# distance in kilometers
distance_calc_km = distance.distance(location_1_gps, location_2_gps).km
print(distance_calc_km)
# Out:
# 57.868661874716246
